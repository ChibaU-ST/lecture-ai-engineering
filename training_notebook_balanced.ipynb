# %% [markdown]
# <a href="https://colab.research.google.com/github/ChibaU-ST/lecture-ai-engineering/blob/master/training_notebook_balanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 ひらがなGPT - Transformerで日本語文章生成
#
# このノートブックでは、Transformerアーキテクチャを使って日本語（ひらがな）の文章を生成するモデルを学習します。
#
# ## 📚 学習内容
# - **Self-Attention（自己注意機構）**: 文脈を理解する仕組み
# - **Transformer**: 現代のAIの基礎となるアーキテクチャ
# - **言語モデル**: 次の文字を予測することで文章を生成
#
# ## 📋 必要なもの
# 1. `input.txt` - 前処理済みのテキストファイル（01_前処理.ipynb で作成）
# 2. GPU（推奨）- 学習を高速化
#
# ---

# %% [markdown]
# ## 1️⃣ ライブラリのインポートと設定

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import os
from datetime import datetime

print("="*70)
print("  ひらがなGPT - Transformer言語モデル")
print("="*70)
print(f"実行開始時刻: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"PyTorchバージョン: {torch.__version__}")
print(f"CUDA利用可能: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU名: {torch.cuda.get_device_name(0)}")
print("="*70)
# Out:
# ======================================================================
#   ひらがなGPT - Transformer言語モデル
# ======================================================================
# 実行開始時刻: 2025-10-06 13:13:00
# PyTorchバージョン: 2.8.0+cu126
# CUDA利用可能: True
# GPU名: NVIDIA A100-SXM4-40GB
# ======================================================================

# %% [markdown]
# ## 2️⃣ ハイパーパラメータの設定
#
# これらのパラメータがモデルの性能を決定します。
#
# ### 過学習対策のポイント
# - **適度なモデルサイズ**: データ量に合わせた大きさ
# - **Dropout**: ランダムにニューロンを無効化
# - **Weight Decay**: パラメータが大きくなりすぎるのを防ぐ
# - **Gradient Clipping**: 学習の安定化
# - **Early Stopping**: 過学習の兆候で自動停止

# %%
# === データ処理 ===
batch_size = 32      # 一度に処理する文章数
block_size = 128     # 一度に見る文字数（64→128に拡大）

# === 学習制御 ===
max_iters = 8000     # 最大学習回数
eval_interval = 100  # 評価間隔
learning_rate = 3e-4 # 学習率
eval_iters = 200     # 評価時のバッチ数

# === Transformer構造（データ量に最適化）===
n_embd = 256         # 埋め込み次元数（128→256）
n_head = 8           # Attention Headの数（4→8）
n_layer = 6          # Transformerブロックの層数（4→6）
dropout = 0.25       # Dropout率（0.2→0.25で過学習対策強化）

# === 過学習対策 ===
weight_decay = 0.1   # L2正則化
grad_clip = 1.0      # 勾配クリッピング

# === チェックポイント ===
checkpoint_interval = 100  # 保存間隔
checkpoint_dir = 'checkpoints'

# === Early Stopping ===
patience = 10        # 改善なしで待つ回数
min_delta = 0.005    # 改善とみなす最小差

device = 'cuda' if torch.cuda.is_available() else 'cpu'

print("\n📊 ハイパーパラメータ設定")
print("-"*70)
print(f"  デバイス: {device}")
print(f"  バッチサイズ: {batch_size}")
print(f"  コンテキスト長: {block_size}文字")
print(f"\n  【モデル構造】")
print(f"  埋め込み次元: {n_embd}")
print(f"  Attention Head数: {n_head}")
print(f"  Transformer層数: {n_layer}")
print(f"  予想パラメータ数: 約{(n_embd * n_embd * n_layer * 12) / 1e6:.1f}M")
print(f"\n  【過学習対策】")
print(f"  Dropout率: {dropout}")
print(f"  Weight Decay: {weight_decay}")
print(f"  Gradient Clipping: {grad_clip}")
print(f"  Early Stopping: {patience}回")
print(f"\n  【学習設定】")
print(f"  学習率: {learning_rate}")
print(f"  最大イテレーション: {max_iters}")
print("-"*70)

os.makedirs(checkpoint_dir, exist_ok=True)
# Out:
# 📊 ハイパーパラメータ設定
# ----------------------------------------------------------------------
#   デバイス: cuda
#   バッチサイズ: 32
#   コンテキスト長: 128文字
#
#   【モデル構造】
#   埋め込み次元: 256
#   Attention Head数: 8
#   Transformer層数: 6
#   予想パラメータ数: 約4.7M
#
#   【過学習対策】
#   Dropout率: 0.25
#   Weight Decay: 0.1
#   Gradient Clipping: 1.0
#   Early Stopping: 10回
#
#   【学習設定】
#   学習率: 0.0003
#   最大イテレーション: 8000
# ----------------------------------------------------------------------

# %% [markdown]
# ## 3️⃣ データの読み込みと前処理
#
# `input.txt`（前処理済み）をアップロードしてください。

# %%
print("\n📖 データ読み込み中...")
print("-"*70)

if not os.path.exists('input.txt'):
    print("❌ input.txt が見つかりません")
    print("\n前処理ノートブック（01_前処理.ipynb）を先に実行してください。")
    print("または、前処理済みの input.txt をアップロードしてください。")
    raise FileNotFoundError("input.txt")

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("✅ input.txt を読み込みました")

# 文字セットの作成
chars = sorted(list(set(text)))
vocab_size = len(chars)

print(f"\n📊 データ統計")
print(f"  総文字数: {len(text):,} 文字")
print(f"  語彙サイズ: {vocab_size} 種類")
print(f"  文字セット: {''.join(chars)}")

if vocab_size > 70:
    print(f"\n  ⚠️ 語彙サイズが大きい ({vocab_size})")
    print(f"     前処理で濁点分離を有効にすると改善する可能性があります")

# エンコード・デコード関数
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

# データの分割
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

print(f"\n📂 データ分割")
print(f"  訓練データ: {len(train_data):,} 文字 (90%)")
print(f"  検証データ: {len(val_data):,} 文字 (10%)")
print("-"*70)

print("\n📝 サンプルテキスト（最初の200文字）:")
print("-"*70)
print(text[:200])
print("-"*70)
# Out:
# 📖 データ読み込み中...
# ----------------------------------------------------------------------
# ✅ input.txt を読み込みました
#
# 📊 データ統計
#   総文字数: 944,046 文字
#   語彙サイズ: 85 種類
#   文字セット:
#  AK―…○、。「」ぁあぃいうぇえぉおかきくけこさしすせそたちっつてとなにぬねのはひふへほまみむめもゃやゅゆょよらりるれろわをん゛゜イシハャリンヴー新！（）？ＡＢＨＫＮ
#
#   ⚠️ 語彙サイズが大きい (85)
#      前処理で濁点分離を有効にすると改善する可能性があります
#
# 📂 データ分割
#   訓練データ: 849,641 文字 (90%)
#   検証データ: 94,405 文字 (10%)
# ----------------------------------------------------------------------
#
# 📝 サンプルテキスト（最初の200文字）:
# ----------------------------------------------------------------------
# なつめ そうせき 「こころ」
# し゛ょう せんせい と わたし
# いち
# わたくしは そのひとを つねに せんせいと よんて゛いた。 た゛から ここて゛も たた゛ せんせいと かくた゛けて゛ ほんみょうは うちあけない。 これは せけんを はは゛かる えんりょと いうよりも、 そのほうか゛ わたくしに とって しせ゛んた゛からて゛ある。 わたくしは そのひとの きおくを よひ゛おこすこ゛とに、 すく゛
# ----------------------------------------------------------------------

# %%
# データ取得関数
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

print("✅ データ処理関数を定義しました")
# Out:
# ✅ データ処理関数を定義しました

# %% [markdown]
# ## 4️⃣ Transformerモデルの定義
#
# ### 🧠 Transformerの構成要素
#
# 1. **Self-Attention**: 文章内の単語間の関係を学習
# 2. **Multi-Head Attention**: 複数の視点から文脈を捉える
# 3. **Feed Forward**: 各単語の特徴を変換
# 4. **Layer Normalization**: 学習を安定化
# 5. **Residual Connection**: 深いネットワークの学習を可能に

# %%
print("\n🏗️  モデル構築中...")
print("-"*70)

class Head(nn.Module):
    """Self-Attention Head"""

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    """複数のAttention Headを並列実行"""

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    """Feed Forward Network"""

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """Transformerブロック"""

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):
    """GPT言語モデル"""

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

print("✅ すべてのクラスを定義しました")
# Out:
# 🏗️  モデル構築中...
# ----------------------------------------------------------------------
# ✅ すべてのクラスを定義しました

# %%
# モデルのインスタンス化
model = GPTLanguageModel()
m = model.to(device)

# パラメータ数の計算
n_params = sum(p.numel() for p in m.parameters())

print("\n✨ モデル構築完了")
print("-"*70)
print(f"  総パラメータ数: {n_params:,} ({n_params/1e6:.2f}M)")
print(f"  デバイス: {device}")
print(f"  モデルサイズ: 約{n_params * 4 / 1024 / 1024:.1f}MB (float32)")
print("-"*70)

# モデル構造の表示
print("\n🏗️  モデル構造:")
print(f"  Token Embedding: {vocab_size} → {n_embd}")
print(f"  Position Embedding: {block_size} → {n_embd}")
print(f"  Transformer Blocks: {n_layer}層")
print(f"    ├─ Multi-Head Attention: {n_head}heads × {n_embd//n_head}dim")
print(f"    └─ Feed Forward: {n_embd} → {4*n_embd} → {n_embd}")
print(f"  Output Layer: {n_embd} → {vocab_size}")
print("-"*70)
# Out:
# ✨ モデル構築完了
# ----------------------------------------------------------------------
#   総パラメータ数: 4,810,837 (4.81M)
#   デバイス: cuda
#   モデルサイズ: 約18.4MB (float32)
# ----------------------------------------------------------------------
#
# 🏗️  モデル構造:
#   Token Embedding: 85 → 256
#   Position Embedding: 128 → 256
#   Transformer Blocks: 6層
#     ├─ Multi-Head Attention: 8heads × 32dim
#     └─ Feed Forward: 256 → 1024 → 256
#   Output Layer: 256 → 85
# ----------------------------------------------------------------------

# %% [markdown]
# ## 5️⃣ モデルの学習
#
# AdamWオプティマイザ（Weight Decay付き）を使用して学習します。

# %%
# Weight Decay付きオプティマイザ
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

checkpoints = []
best_val_loss = float('inf')
patience_counter = 0

print("\n🚀 学習開始")
print("="*70)
print(f"開始時刻: {datetime.now().strftime('%H:%M:%S')}")
print(f"最大イテレーション: {max_iters}")
print(f"評価間隔: {eval_interval}回")
print(f"チェックポイント保存: {checkpoint_interval}回ごと")
print(f"\n過学習対策:")
print(f"  - Dropout: {dropout}")
print(f"  - Weight Decay: {weight_decay}")
print(f"  - Gradient Clipping: {grad_clip}")
print(f"  - Early Stopping: patience={patience}, min_delta={min_delta}")
print("="*70)

start_time = datetime.now()

for iter in range(max_iters):
    # 定期的な評価
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()

        # Train/Val Gapの計算（過学習の指標）
        gap = losses['val'].item() - losses['train'].item()

        # プログレスバー風の表示
        progress = iter / max_iters * 100
        bar_length = 30
        filled = int(bar_length * iter / max_iters)
        bar = '█' * filled + '░' * (bar_length - filled)

        elapsed = (datetime.now() - start_time).total_seconds()
        eta = elapsed / (iter + 1) * (max_iters - iter) if iter > 0 else 0

        print(f"\n[{bar}] {progress:5.1f}%")
        print(f"ステップ {iter:5d}/{max_iters} | "
              f"{int(elapsed//60)}:{int(elapsed%60):02d} (残り{int(eta//60)}分)")
        print(f"Train: {losses['train']:.4f} | Val: {losses['val']:.4f} | Gap: {gap:.4f}")

        # Early Stoppingチェック
        if losses['val'] < best_val_loss - min_delta:
            best_val_loss = losses['val']
            patience_counter = 0
            print(f"  ✨ 新記録！ Val Loss: {best_val_loss:.4f}")
        else:
            patience_counter += 1
            if patience_counter > 0:
                print(f"  ⏳ 改善なし: {patience_counter}/{patience}回")

        # 過学習警告
        if gap > 0.5:
            print(f"  ⚠️ 過学習の兆候 (Gap={gap:.4f})")
        elif gap < 0.2:
            print(f"  ✅ 良好な汎化 (Gap={gap:.4f})")

        if patience_counter >= patience:
            print(f"\n🛑 Early Stopping: {patience}回連続で改善なし")
            break

    # チェックポイント保存
    if iter % checkpoint_interval == 0 and iter > 0:
        checkpoint_path = os.path.join(checkpoint_dir, f'model_iter_{iter}.pt')
        torch.save({
            'iter': iter,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': losses['train'].item() if iter % eval_interval == 0 else None,
            'val_loss': losses['val'].item() if iter % eval_interval == 0 else None,
        }, checkpoint_path)
        checkpoints.append((iter, checkpoint_path))
        print(f"  💾 チェックポイント保存: iter_{iter}.pt")

    # 学習ステップ
    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()

    # Gradient Clipping（勾配爆発防止）
    torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

    optimizer.step()

# 最終モデル保存
final_path = os.path.join(checkpoint_dir, 'model_final.pt')
torch.save({
    'iter': iter,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
}, final_path)
checkpoints.append((iter, final_path))

total_time = (datetime.now() - start_time).total_seconds()
final_gap = losses['val'].item() - losses['train'].item()

print("\n")
print("="*70)
print("✅ 学習完了！")
print(f"終了時刻: {datetime.now().strftime('%H:%M:%S')}")
print(f"所要時間: {int(total_time//60)}分{int(total_time%60)}秒")
print(f"\n最終Loss:")
print(f"  Train: {losses['train']:.4f}")
print(f"  Val: {losses['val']:.4f}")
print(f"  Gap: {final_gap:.4f}")
print(f"\nベストVal Loss: {best_val_loss:.4f}")
print(f"保存されたチェックポイント: {len(checkpoints)}個")

# 最終評価
if final_gap < 0.3:
    print("\n🎉 優秀！過学習を抑えて学習できました")
elif final_gap < 0.5:
    print("\n👍 良好！適度な汎化性能です")
else:
    print("\n⚠️ 過学習気味です。データ量を増やすか、モデルを小さくすることを検討してください")

print("="*70)
# Out:
# 🚀 学習開始
# ======================================================================
# 開始時刻: 13:14:00
# 最大イテレーション: 8000
# 評価間隔: 100回
# チェックポイント保存: 100回ごと
#
# 過学習対策:
#   - Dropout: 0.25
#   - Weight Decay: 0.1
#   - Gradient Clipping: 1.0
#   - Early Stopping: patience=10, min_delta=0.005
# ======================================================================
#
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0.0%
# ステップ     0/8000 | 0:06 (残り0分)
# Train: 4.6146 | Val: 4.6225 | Gap: 0.0079
#   ✨ 新記録！ Val Loss: 4.6225
#   ✅ 良好な汎化 (Gap=0.0079)
#
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   1.2%
# ステップ   100/8000 | 0:19 (残り26分)
# Train: 2.8258 | Val: 2.8485 | Gap: 0.0228
#   ✨ 新記録！ Val Loss: 2.8485
#   ✅ 良好な汎化 (Gap=0.0228)
#   💾 チェックポイント保存: iter_100.pt
#
# [░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   2.5%
# ステップ   200/8000 | 0:33 (残り21分)
# Train: 2.7801 | Val: 2.8036 | Gap: 0.0235
#   ✨ 新記録！ Val Loss: 2.8036
#   ✅ 良好な汎化 (Gap=0.0235)
#   💾 チェックポイント保存: iter_200.pt
#
# [█░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   3.8%
# ステップ   300/8000 | 0:46 (残り19分)
# Train: 2.7490 | Val: 2.7691 | Gap: 0.0201
#   ✨ 新記録！ Val Loss: 2.7691
#   ✅ 良好な汎化 (Gap=0.0201)
#   💾 チェックポイント保存: iter_300.pt
#
# [█░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   5.0%
# ステップ   400/8000 | 0:59 (残り18分)
# Train: 2.6995 | Val: 2.7188 | Gap: 0.0193
#   ✨ 新記録！ Val Loss: 2.7188
#   ✅ 良好な汎化 (Gap=0.0193)
#   💾 チェックポイント保存: iter_400.pt
#
# [█░░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   6.2%
# ステップ   500/8000 | 1:13 (残り18分)
# Train: 2.6211 | Val: 2.6423 | Gap: 0.0212
#   ✨ 新記録！ Val Loss: 2.6423
#   ✅ 良好な汎化 (Gap=0.0212)
#   💾 チェックポイント保存: iter_500.pt
#
# [██░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   7.5%
# ステップ   600/8000 | 1:26 (残り17分)
# Train: 2.5125 | Val: 2.5337 | Gap: 0.0212
#   ✨ 新記録！ Val Loss: 2.5337
#   ✅ 良好な汎化 (Gap=0.0212)
#   💾 チェックポイント保存: iter_600.pt
#
# [██░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   8.8%
# ステップ   700/8000 | 1:40 (残り17分)
# Train: 2.4439 | Val: 2.4597 | Gap: 0.0158
#   ✨ 新記録！ Val Loss: 2.4597
#   ✅ 良好な汎化 (Gap=0.0158)
#   💾 チェックポイント保存: iter_700.pt
#
# [███░░░░░░░░░░░░░░░░░░░░░░░░░░░]  10.0%
# ステップ   800/8000 | 1:53 (残り16分)
# Train: 2.3857 | Val: 2.4114 | Gap: 0.0258
#   ✨ 新記録！ Val Loss: 2.4114
#   ✅ 良好な汎化 (Gap=0.0258)
#   💾 チェックポイント保存: iter_800.pt
#
# [███░░░░░░░░░░░░░░░░░░░░░░░░░░░]  11.2%
# ステップ   900/8000 | 2:06 (残り16分)
# Train: 2.3322 | Val: 2.3598 | Gap: 0.0276
#   ✨ 新記録！ Val Loss: 2.3598
#   ✅ 良好な汎化 (Gap=0.0276)
#   💾 チェックポイント保存: iter_900.pt
#
# [███░░░░░░░░░░░░░░░░░░░░░░░░░░░]  12.5%
# ステップ  1000/8000 | 2:20 (残り16分)
# Train: 2.2841 | Val: 2.3266 | Gap: 0.0426
#   ✨ 新記録！ Val Loss: 2.3266
#   ✅ 良好な汎化 (Gap=0.0426)
#   💾 チェックポイント保存: iter_1000.pt
#
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░]  13.8%
# ステップ  1100/8000 | 2:33 (残り16分)
# Train: 2.2527 | Val: 2.2889 | Gap: 0.0362
#   ✨ 新記録！ Val Loss: 2.2889
#   ✅ 良好な汎化 (Gap=0.0362)
#   💾 チェックポイント保存: iter_1100.pt
#
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░]  15.0%
# ステップ  1200/8000 | 2:46 (残り15分)
# Train: 2.2040 | Val: 2.2506 | Gap: 0.0466
#   ✨ 新記録！ Val Loss: 2.2506
#   ✅ 良好な汎化 (Gap=0.0466)
#   💾 チェックポイント保存: iter_1200.pt
#
# [████░░░░░░░░░░░░░░░░░░░░░░░░░░]  16.2%
# ステップ  1300/8000 | 3:00 (残り15分)
# Train: 2.1859 | Val: 2.2234 | Gap: 0.0375
#   ✨ 新記録！ Val Loss: 2.2234
#   ✅ 良好な汎化 (Gap=0.0375)
#   💾 チェックポイント保存: iter_1300.pt
#
# [█████░░░░░░░░░░░░░░░░░░░░░░░░░]  17.5%
# ステップ  1400/8000 | 3:13 (残り15分)
# Train: 2.1499 | Val: 2.1942 | Gap: 0.0443
#   ✨ 新記録！ Val Loss: 2.1942
#   ✅ 良好な汎化 (Gap=0.0443)
#   💾 チェックポイント保存: iter_1400.pt
#
# [█████░░░░░░░░░░░░░░░░░░░░░░░░░]  18.8%
# ステップ  1500/8000 | 3:26 (残り14分)
# Train: 2.1191 | Val: 2.1700 | Gap: 0.0509
#   ✨ 新記録！ Val Loss: 2.1700
#   ✅ 良好な汎化 (Gap=0.0509)
#   💾 チェックポイント保存: iter_1500.pt
#
# [██████░░░░░░░░░░░░░░░░░░░░░░░░]  20.0%
# ステップ  1600/8000 | 3:40 (残り14分)
# Train: 2.0979 | Val: 2.1528 | Gap: 0.0549
#   ✨ 新記録！ Val Loss: 2.1528
#   ✅ 良好な汎化 (Gap=0.0549)
#   💾 チェックポイント保存: iter_1600.pt
#
# [██████░░░░░░░░░░░░░░░░░░░░░░░░]  21.2%
# ステップ  1700/8000 | 3:53 (残り14分)
# Train: 2.0713 | Val: 2.1265 | Gap: 0.0552
#   ✨ 新記録！ Val Loss: 2.1265
#   ✅ 良好な汎化 (Gap=0.0552)
#   💾 チェックポイント保存: iter_1700.pt
#
# [██████░░░░░░░░░░░░░░░░░░░░░░░░]  22.5%
# ステップ  1800/8000 | 4:06 (残り14分)
# Train: 2.0482 | Val: 2.1098 | Gap: 0.0616
#   ✨ 新記録！ Val Loss: 2.1098
#   ✅ 良好な汎化 (Gap=0.0616)
#   💾 チェックポイント保存: iter_1800.pt
#
# [███████░░░░░░░░░░░░░░░░░░░░░░░]  23.8%
# ステップ  1900/8000 | 4:20 (残り13分)
# Train: 2.0290 | Val: 2.0922 | Gap: 0.0632
#   ✨ 新記録！ Val Loss: 2.0922
#   ✅ 良好な汎化 (Gap=0.0632)
#   💾 チェックポイント保存: iter_1900.pt
#
# [███████░░░░░░░░░░░░░░░░░░░░░░░]  25.0%
# ステップ  2000/8000 | 4:33 (残り13分)
# Train: 2.0155 | Val: 2.0740 | Gap: 0.0585
#   ✨ 新記録！ Val Loss: 2.0740
#   ✅ 良好な汎化 (Gap=0.0585)
#   💾 チェックポイント保存: iter_2000.pt
#
# [███████░░░░░░░░░░░░░░░░░░░░░░░]  26.2%
# ステップ  2100/8000 | 4:46 (残り13分)
# Train: 1.9945 | Val: 2.0607 | Gap: 0.0663
#   ✨ 新記録！ Val Loss: 2.0607
#   ✅ 良好な汎化 (Gap=0.0663)
#   💾 チェックポイント保存: iter_2100.pt
#
# [████████░░░░░░░░░░░░░░░░░░░░░░]  27.5%
# ステップ  2200/8000 | 5:00 (残り13分)
# Train: 1.9836 | Val: 2.0464 | Gap: 0.0628
#   ✨ 新記録！ Val Loss: 2.0464
#   ✅ 良好な汎化 (Gap=0.0628)
#   💾 チェックポイント保存: iter_2200.pt
#
# [████████░░░░░░░░░░░░░░░░░░░░░░]  28.7%
# ステップ  2300/8000 | 5:13 (残り12分)
# Train: 1.9618 | Val: 2.0290 | Gap: 0.0672
#   ✨ 新記録！ Val Loss: 2.0290
#   ✅ 良好な汎化 (Gap=0.0672)
#   💾 チェックポイント保存: iter_2300.pt
#
# [█████████░░░░░░░░░░░░░░░░░░░░░]  30.0%
# ステップ  2400/8000 | 5:26 (残り12分)
# Train: 1.9515 | Val: 2.0289 | Gap: 0.0773
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.0773)
#   💾 チェックポイント保存: iter_2400.pt
#
# [█████████░░░░░░░░░░░░░░░░░░░░░]  31.2%
# ステップ  2500/8000 | 5:40 (残り12分)
# Train: 1.9393 | Val: 2.0181 | Gap: 0.0788
#   ✨ 新記録！ Val Loss: 2.0181
#   ✅ 良好な汎化 (Gap=0.0788)
#   💾 チェックポイント保存: iter_2500.pt
#
# [█████████░░░░░░░░░░░░░░░░░░░░░]  32.5%
# ステップ  2600/8000 | 5:53 (残り12分)
# Train: 1.9263 | Val: 2.0007 | Gap: 0.0745
#   ✨ 新記録！ Val Loss: 2.0007
#   ✅ 良好な汎化 (Gap=0.0745)
#   💾 チェックポイント保存: iter_2600.pt
#
# [██████████░░░░░░░░░░░░░░░░░░░░]  33.8%
# ステップ  2700/8000 | 6:06 (残り11分)
# Train: 1.9112 | Val: 1.9976 | Gap: 0.0864
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.0864)
#   💾 チェックポイント保存: iter_2700.pt
#
# [██████████░░░░░░░░░░░░░░░░░░░░]  35.0%
# ステップ  2800/8000 | 6:20 (残り11分)
# Train: 1.8977 | Val: 1.9777 | Gap: 0.0800
#   ✨ 新記録！ Val Loss: 1.9777
#   ✅ 良好な汎化 (Gap=0.0800)
#   💾 チェックポイント保存: iter_2800.pt
#
# [██████████░░░░░░░░░░░░░░░░░░░░]  36.2%
# ステップ  2900/8000 | 6:33 (残り11分)
# Train: 1.8897 | Val: 1.9821 | Gap: 0.0924
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.0924)
#   💾 チェックポイント保存: iter_2900.pt
#
# [███████████░░░░░░░░░░░░░░░░░░░]  37.5%
# ステップ  3000/8000 | 6:46 (残り11分)
# Train: 1.8784 | Val: 1.9696 | Gap: 0.0912
#   ✨ 新記録！ Val Loss: 1.9696
#   ✅ 良好な汎化 (Gap=0.0912)
#   💾 チェックポイント保存: iter_3000.pt
#
# [███████████░░░░░░░░░░░░░░░░░░░]  38.8%
# ステップ  3100/8000 | 7:00 (残り11分)
# Train: 1.8698 | Val: 1.9581 | Gap: 0.0883
#   ✨ 新記録！ Val Loss: 1.9581
#   ✅ 良好な汎化 (Gap=0.0883)
#   💾 チェックポイント保存: iter_3100.pt
#
# [████████████░░░░░░░░░░░░░░░░░░]  40.0%
# ステップ  3200/8000 | 7:13 (残り10分)
# Train: 1.8546 | Val: 1.9520 | Gap: 0.0974
#   ✨ 新記録！ Val Loss: 1.9520
#   ✅ 良好な汎化 (Gap=0.0974)
#   💾 チェックポイント保存: iter_3200.pt
#
# [████████████░░░░░░░░░░░░░░░░░░]  41.2%
# ステップ  3300/8000 | 7:26 (残り10分)
# Train: 1.8526 | Val: 1.9474 | Gap: 0.0947
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.0947)
#   💾 チェックポイント保存: iter_3300.pt
#
# [████████████░░░░░░░░░░░░░░░░░░]  42.5%
# ステップ  3400/8000 | 7:40 (残り10分)
# Train: 1.8371 | Val: 1.9390 | Gap: 0.1019
#   ✨ 新記録！ Val Loss: 1.9390
#   ✅ 良好な汎化 (Gap=0.1019)
#   💾 チェックポイント保存: iter_3400.pt
#
# [█████████████░░░░░░░░░░░░░░░░░]  43.8%
# ステップ  3500/8000 | 7:53 (残り10分)
# Train: 1.8405 | Val: 1.9426 | Gap: 0.1021
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1021)
#   💾 チェックポイント保存: iter_3500.pt
#
# [█████████████░░░░░░░░░░░░░░░░░]  45.0%
# ステップ  3600/8000 | 8:06 (残り9分)
# Train: 1.8239 | Val: 1.9282 | Gap: 0.1044
#   ✨ 新記録！ Val Loss: 1.9282
#   ✅ 良好な汎化 (Gap=0.1044)
#   💾 チェックポイント保存: iter_3600.pt
#
# [█████████████░░░░░░░░░░░░░░░░░]  46.2%
# ステップ  3700/8000 | 8:20 (残り9分)
# Train: 1.8182 | Val: 1.9323 | Gap: 0.1141
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1141)
#   💾 チェックポイント保存: iter_3700.pt
#
# [██████████████░░░░░░░░░░░░░░░░]  47.5%
# ステップ  3800/8000 | 8:33 (残り9分)
# Train: 1.8119 | Val: 1.9237 | Gap: 0.1118
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1118)
#   💾 チェックポイント保存: iter_3800.pt
#
# [██████████████░░░░░░░░░░░░░░░░]  48.8%
# ステップ  3900/8000 | 8:47 (残り9分)
# Train: 1.8053 | Val: 1.9204 | Gap: 0.1151
#   ✨ 新記録！ Val Loss: 1.9204
#   ✅ 良好な汎化 (Gap=0.1151)
#   💾 チェックポイント保存: iter_3900.pt
#
# [███████████████░░░░░░░░░░░░░░░]  50.0%
# ステップ  4000/8000 | 9:00 (残り9分)
# Train: 1.7962 | Val: 1.9157 | Gap: 0.1195
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1195)
#   💾 チェックポイント保存: iter_4000.pt
#
# [███████████████░░░░░░░░░░░░░░░]  51.2%
# ステップ  4100/8000 | 9:13 (残り8分)
# Train: 1.7873 | Val: 1.9048 | Gap: 0.1175
#   ✨ 新記録！ Val Loss: 1.9048
#   ✅ 良好な汎化 (Gap=0.1175)
#   💾 チェックポイント保存: iter_4100.pt
#
# [███████████████░░░░░░░░░░░░░░░]  52.5%
# ステップ  4200/8000 | 9:27 (残り8分)
# Train: 1.7868 | Val: 1.9062 | Gap: 0.1193
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1193)
#   💾 チェックポイント保存: iter_4200.pt
#
# [████████████████░░░░░░░░░░░░░░]  53.8%
# ステップ  4300/8000 | 9:40 (残り8分)
# Train: 1.7746 | Val: 1.9033 | Gap: 0.1287
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1287)
#   💾 チェックポイント保存: iter_4300.pt
#
# [████████████████░░░░░░░░░░░░░░]  55.0%
# ステップ  4400/8000 | 9:54 (残り8分)
# Train: 1.7696 | Val: 1.8970 | Gap: 0.1274
#   ✨ 新記録！ Val Loss: 1.8970
#   ✅ 良好な汎化 (Gap=0.1274)
#   💾 チェックポイント保存: iter_4400.pt
#
# [████████████████░░░░░░░░░░░░░░]  56.2%
# ステップ  4500/8000 | 10:07 (残り7分)
# Train: 1.7625 | Val: 1.8956 | Gap: 0.1331
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1331)
#   💾 チェックポイント保存: iter_4500.pt
#
# [█████████████████░░░░░░░░░░░░░]  57.5%
# ステップ  4600/8000 | 10:21 (残り7分)
# Train: 1.7562 | Val: 1.8821 | Gap: 0.1258
#   ✨ 新記録！ Val Loss: 1.8821
#   ✅ 良好な汎化 (Gap=0.1258)
#   💾 チェックポイント保存: iter_4600.pt
#
# [█████████████████░░░░░░░░░░░░░]  58.8%
# ステップ  4700/8000 | 10:34 (残り7分)
# Train: 1.7475 | Val: 1.8788 | Gap: 0.1312
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1312)
#   💾 チェックポイント保存: iter_4700.pt
#
# [██████████████████░░░░░░░░░░░░]  60.0%
# ステップ  4800/8000 | 10:48 (残り7分)
# Train: 1.7494 | Val: 1.8841 | Gap: 0.1347
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1347)
#   💾 チェックポイント保存: iter_4800.pt
#
# [██████████████████░░░░░░░░░░░░]  61.3%
# ステップ  4900/8000 | 11:01 (残り6分)
# Train: 1.7355 | Val: 1.8725 | Gap: 0.1369
#   ✨ 新記録！ Val Loss: 1.8725
#   ✅ 良好な汎化 (Gap=0.1369)
#   💾 チェックポイント保存: iter_4900.pt
#
# [██████████████████░░░░░░░░░░░░]  62.5%
# ステップ  5000/8000 | 11:14 (残り6分)
# Train: 1.7329 | Val: 1.8692 | Gap: 0.1363
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1363)
#   💾 チェックポイント保存: iter_5000.pt
#
# [███████████████████░░░░░░░░░░░]  63.7%
# ステップ  5100/8000 | 11:28 (残り6分)
# Train: 1.7310 | Val: 1.8756 | Gap: 0.1446
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1446)
#   💾 チェックポイント保存: iter_5100.pt
#
# [███████████████████░░░░░░░░░░░]  65.0%
# ステップ  5200/8000 | 11:42 (残り6分)
# Train: 1.7189 | Val: 1.8650 | Gap: 0.1462
#   ✨ 新記録！ Val Loss: 1.8650
#   ✅ 良好な汎化 (Gap=0.1462)
#   💾 チェックポイント保存: iter_5200.pt
#
# [███████████████████░░░░░░░░░░░]  66.2%
# ステップ  5300/8000 | 11:56 (残り6分)
# Train: 1.7193 | Val: 1.8633 | Gap: 0.1440
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1440)
#   💾 チェックポイント保存: iter_5300.pt
#
# [████████████████████░░░░░░░░░░]  67.5%
# ステップ  5400/8000 | 12:09 (残り5分)
# Train: 1.7127 | Val: 1.8620 | Gap: 0.1493
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1493)
#   💾 チェックポイント保存: iter_5400.pt
#
# [████████████████████░░░░░░░░░░]  68.8%
# ステップ  5500/8000 | 12:23 (残り5分)
# Train: 1.7148 | Val: 1.8570 | Gap: 0.1422
#   ✨ 新記録！ Val Loss: 1.8570
#   ✅ 良好な汎化 (Gap=0.1422)
#   💾 チェックポイント保存: iter_5500.pt
#
# [█████████████████████░░░░░░░░░]  70.0%
# ステップ  5600/8000 | 12:37 (残り5分)
# Train: 1.7055 | Val: 1.8533 | Gap: 0.1478
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1478)
#   💾 チェックポイント保存: iter_5600.pt
#
# [█████████████████████░░░░░░░░░]  71.2%
# ステップ  5700/8000 | 12:50 (残り5分)
# Train: 1.7089 | Val: 1.8574 | Gap: 0.1485
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1485)
#   💾 チェックポイント保存: iter_5700.pt
#
# [█████████████████████░░░░░░░░░]  72.5%
# ステップ  5800/8000 | 13:04 (残り4分)
# Train: 1.7010 | Val: 1.8467 | Gap: 0.1457
#   ✨ 新記録！ Val Loss: 1.8467
#   ✅ 良好な汎化 (Gap=0.1457)
#   💾 チェックポイント保存: iter_5800.pt
#
# [██████████████████████░░░░░░░░]  73.8%
# ステップ  5900/8000 | 13:17 (残り4分)
# Train: 1.6940 | Val: 1.8505 | Gap: 0.1566
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1566)
#   💾 チェックポイント保存: iter_5900.pt
#
# [██████████████████████░░░░░░░░]  75.0%
# ステップ  6000/8000 | 13:31 (残り4分)
# Train: 1.6837 | Val: 1.8479 | Gap: 0.1642
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1642)
#   💾 チェックポイント保存: iter_6000.pt
#
# [██████████████████████░░░░░░░░]  76.2%
# ステップ  6100/8000 | 13:44 (残り4分)
# Train: 1.6862 | Val: 1.8426 | Gap: 0.1564
#   ⏳ 改善なし: 3/10回
#   ✅ 良好な汎化 (Gap=0.1564)
#   💾 チェックポイント保存: iter_6100.pt
#
# [███████████████████████░░░░░░░]  77.5%
# ステップ  6200/8000 | 13:58 (残り4分)
# Train: 1.6806 | Val: 1.8468 | Gap: 0.1662
#   ⏳ 改善なし: 4/10回
#   ✅ 良好な汎化 (Gap=0.1662)
#   💾 チェックポイント保存: iter_6200.pt
#
# [███████████████████████░░░░░░░]  78.8%
# ステップ  6300/8000 | 14:11 (残り3分)
# Train: 1.6755 | Val: 1.8464 | Gap: 0.1709
#   ⏳ 改善なし: 5/10回
#   ✅ 良好な汎化 (Gap=0.1709)
#   💾 チェックポイント保存: iter_6300.pt
#
# [████████████████████████░░░░░░]  80.0%
# ステップ  6400/8000 | 14:24 (残り3分)
# Train: 1.6748 | Val: 1.8450 | Gap: 0.1703
#   ⏳ 改善なし: 6/10回
#   ✅ 良好な汎化 (Gap=0.1703)
#   💾 チェックポイント保存: iter_6400.pt
#
# [████████████████████████░░░░░░]  81.2%
# ステップ  6500/8000 | 14:38 (残り3分)
# Train: 1.6624 | Val: 1.8442 | Gap: 0.1818
#   ⏳ 改善なし: 7/10回
#   ✅ 良好な汎化 (Gap=0.1818)
#   💾 チェックポイント保存: iter_6500.pt
#
# [████████████████████████░░░░░░]  82.5%
# ステップ  6600/8000 | 14:51 (残り3分)
# Train: 1.6675 | Val: 1.8482 | Gap: 0.1807
#   ⏳ 改善なし: 8/10回
#   ✅ 良好な汎化 (Gap=0.1807)
#   💾 チェックポイント保存: iter_6600.pt
#
# [█████████████████████████░░░░░]  83.8%
# ステップ  6700/8000 | 15:04 (残り2分)
# Train: 1.6632 | Val: 1.8336 | Gap: 0.1703
#   ✨ 新記録！ Val Loss: 1.8336
#   ✅ 良好な汎化 (Gap=0.1703)
#   💾 チェックポイント保存: iter_6700.pt
#
# [█████████████████████████░░░░░]  85.0%
# ステップ  6800/8000 | 15:18 (残り2分)
# Train: 1.6521 | Val: 1.8342 | Gap: 0.1821
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1821)
#   💾 チェックポイント保存: iter_6800.pt
#
# [█████████████████████████░░░░░]  86.2%
# ステップ  6900/8000 | 15:31 (残り2分)
# Train: 1.6512 | Val: 1.8300 | Gap: 0.1787
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1787)
#   💾 チェックポイント保存: iter_6900.pt
#
# [██████████████████████████░░░░]  87.5%
# ステップ  7000/8000 | 15:44 (残り2分)
# Train: 1.6477 | Val: 1.8348 | Gap: 0.1870
#   ⏳ 改善なし: 3/10回
#   ✅ 良好な汎化 (Gap=0.1870)
#   💾 チェックポイント保存: iter_7000.pt
#
# [██████████████████████████░░░░]  88.8%
# ステップ  7100/8000 | 15:58 (残り2分)
# Train: 1.6414 | Val: 1.8322 | Gap: 0.1908
#   ⏳ 改善なし: 4/10回
#   ✅ 良好な汎化 (Gap=0.1908)
#   💾 チェックポイント保存: iter_7100.pt
#
# [███████████████████████████░░░]  90.0%
# ステップ  7200/8000 | 16:11 (残り1分)
# Train: 1.6454 | Val: 1.8362 | Gap: 0.1909
#   ⏳ 改善なし: 5/10回
#   ✅ 良好な汎化 (Gap=0.1909)
#   💾 チェックポイント保存: iter_7200.pt
#
# [███████████████████████████░░░]  91.2%
# ステップ  7300/8000 | 16:24 (残り1分)
# Train: 1.6414 | Val: 1.8279 | Gap: 0.1865
#   ✨ 新記録！ Val Loss: 1.8279
#   ✅ 良好な汎化 (Gap=0.1865)
#   💾 チェックポイント保存: iter_7300.pt
#
# [███████████████████████████░░░]  92.5%
# ステップ  7400/8000 | 16:38 (残り1分)
# Train: 1.6316 | Val: 1.8296 | Gap: 0.1980
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1980)
#   💾 チェックポイント保存: iter_7400.pt
#
# [████████████████████████████░░]  93.8%
# ステップ  7500/8000 | 16:51 (残り1分)
# Train: 1.6317 | Val: 1.8259 | Gap: 0.1942
#   ⏳ 改善なし: 2/10回
#   ✅ 良好な汎化 (Gap=0.1942)
#   💾 チェックポイント保存: iter_7500.pt
#
# [████████████████████████████░░]  95.0%
# ステップ  7600/8000 | 17:04 (残り0分)
# Train: 1.6280 | Val: 1.8191 | Gap: 0.1912
#   ✨ 新記録！ Val Loss: 1.8191
#   ✅ 良好な汎化 (Gap=0.1912)
#   💾 チェックポイント保存: iter_7600.pt
#
# [████████████████████████████░░]  96.2%
# ステップ  7700/8000 | 17:18 (残り0分)
# Train: 1.6205 | Val: 1.8348 | Gap: 0.2143
#   ⏳ 改善なし: 1/10回
#   💾 チェックポイント保存: iter_7700.pt
#
# [█████████████████████████████░]  97.5%
# ステップ  7800/8000 | 17:31 (残り0分)
# Train: 1.6187 | Val: 1.8245 | Gap: 0.2058
#   ⏳ 改善なし: 2/10回
#   💾 チェックポイント保存: iter_7800.pt
#
# [█████████████████████████████░]  98.8%
# ステップ  7900/8000 | 17:45 (残り0分)
# Train: 1.6182 | Val: 1.8120 | Gap: 0.1939
#   ✨ 新記録！ Val Loss: 1.8120
#   ✅ 良好な汎化 (Gap=0.1939)
#   💾 チェックポイント保存: iter_7900.pt
#
# [█████████████████████████████░] 100.0%
# ステップ  7999/8000 | 17:58 (残り0分)
# Train: 1.6195 | Val: 1.8177 | Gap: 0.1982
#   ⏳ 改善なし: 1/10回
#   ✅ 良好な汎化 (Gap=0.1982)
#
#
# ======================================================================
# ✅ 学習完了！
# 終了時刻: 13:31:58
# 所要時間: 17分58秒
#
# 最終Loss:
#   Train: 1.6195
#   Val: 1.8177
#   Gap: 0.1982
#
# ベストVal Loss: 1.8120
# 保存されたチェックポイント: 80個
#
# 🎉 優秀！過学習を抑えて学習できました
# ======================================================================

# %% [markdown]
# ## 6️⃣ 学習経過の確認 - 各チェックポイントでの文章生成
#
# 学習が進むにつれて、生成される文章がどのように改善されるかを確認します。

# %%
print("\n" + "="*70)
print("📊 学習経過の可視化 - 各段階での文章生成")
print("="*70)
print("各チェックポイントで300文字を生成し、学習の進捗を確認します。")
print("最初は意味不明な文字列ですが、徐々に文章らしくなっていきます。")
print("="*70)

for idx, (iter_num, checkpoint_path) in enumerate(checkpoints, 1):
    print(f"\n{'='*70}")
    print(f"📈 チェックポイント {idx}/{len(checkpoints)}: イテレーション {iter_num}回")
    print(f"{'-'*70}")

    # モデルロード
    checkpoint = torch.load(checkpoint_path, weights_only=False)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # Loss情報があれば表示
    if 'train_loss' in checkpoint and checkpoint['train_loss'] is not None:
        train_l = checkpoint['train_loss']
        val_l = checkpoint['val_loss']
        gap = val_l - train_l
        print(f"Train: {train_l:.4f} | Val: {val_l:.4f} | Gap: {gap:.4f}")
        print(f"{'-'*70}")

    # 文章生成
    context = torch.zeros((1, 1), dtype=torch.long, device=device)
    with torch.no_grad():
        generated = decode(model.generate(context, max_new_tokens=300)[0].tolist())

    print(generated)
    print(f"{'-'*70}")

    # 分析コメント
    if iter_num <= 500:
        print("💭 学習初期 - 文字の出現頻度を学習中")
    elif iter_num <= 2000:
        print("💭 学習中期 - 単語や文字列のパターンを獲得")
    elif iter_num <= 5000:
        print("💭 学習後期 - 文章構造や文脈を理解し始めています")
    else:
        print("💭 学習完了 - より自然で意味のある文章を生成")

print("\n" + "="*70)
print("🎉 すべてのチェックポイントのテスト完了")
print("="*70)
# Out:
# ======================================================================
# 📊 学習経過の可視化 - 各段階での文章生成
# ======================================================================
# 各チェックポイントで300文字を生成し、学習の進捗を確認します。
# 最初は意味不明な文字列ですが、徐々に文章らしくなっていきます。
# ======================================================================
#
# ======================================================================
# 📈 チェックポイント 1/80: イテレーション 100回
# ----------------------------------------------------------------------
# Train: 2.8258 | Val: 2.8485 | Gap: 0.0228
# ----------------------------------------------------------------------
#
# 「い し゛ちょうのか゛くにの な して゛ 。 たまして としＮたしけと いいいわの なとこんとあた゛ のきたし゛ゆうし゛、 ちに ろせんは そうに おこと ころとは ほうよくなったらないまくか゛ますし゛ふ゛を きまえしてかほとこと゛ついひとかていし …の あかいた゛んの しそれとか゛ねて゛えて゛よりちんかせた゛ら またりは おしのぁ に もははと゛ょうと こうて゛ くさなっき そこのを なら きいせいって゛にもはな うもと゛を おもった」ときいの いいますくのて゛んもんりかきまた。ぃんかえていに その て゛れするょうこにめて゛は へ まちのろせた゛つ Ｎこう すを し゛して゛さるしんなかんに
# ----------------------------------------------------------------------
# 💭 学習初期 - 文字の出現頻度を学習中
#
# ======================================================================
# 📈 チェックポイント 2/80: イテレーション 200回
# ----------------------------------------------------------------------
# Train: 2.7801 | Val: 2.8036 | Gap: 0.0235
# ----------------------------------------------------------------------
#
# 「か゛もようか けかるまいて゛ たし゛ょう あに た゛ とかくしら こと なる。 あった゛、 なか゛ むか゛きに うして゛するし゛くる きに いのを の いうはいにっていうに まいま、 これてきた゛もい あなるれたし゛か゛か゛んなに きほと ないうに もわりかは゛すうし゛たくのて゛ とききた。 こていて、 い けい か゛ろんの おり ませたの と わるも さし゛ょしなに しくひ゛すしょうみに、 かれとに つも おひさい かすないな しはんか゛ そうし゛ いと、 おを いたの ようにには な かな うた。 しは、 きも うしまさこの な えはに、 ともい いよくっと゛た゛か゛ うと いうには さ
# ----------------------------------------------------------------------
# 💭 学習初期 - 文字の出現頻度を学習中
#
# ======================================================================
# 📈 チェックポイント 3/80: イテレーション 300回
# ----------------------------------------------------------------------
# Train: 2.7490 | Val: 2.7691 | Gap: 0.0201
# ----------------------------------------------------------------------
#
# 「おろえた゛ しのし゛ょうに は し゛を たった た。 くちて゛ょうか゛と、 たの つけめなんは か゛ た゛ふないたす゛ょうに ひ゛りの なかたりを かったら
# 「そうけて゛ け゛ふくしらねきた。 く、 なき ひ゛まふ゛まするた。 よほ゛った。
# ぬくは おハ されは゜うとか゛ ひかしまし゛めに さん なにく き きたしなけ゛かくもらいとから、 いな 「おとの と きなく け゛かられを は おみしょうさた むねたえないうし゛ておりを いか゛んと あさの けたったの した゛ささふ゛、 て゛さ゛もいて゛んけ゛ょう いつの あまなか゛って あれし゛ は かわりん。
# いた゛まえた゛よこは゛ へ かえて゛り
# ----------------------------------------------------------------------
# 💭 学習初期 - 文字の出現頻度を学習中
#
# ======================================================================
# 📈 チェックポイント 4/80: イテレーション 400回
# ----------------------------------------------------------------------
# Train: 2.6995 | Val: 2.7188 | Gap: 0.0193
# ----------------------------------------------------------------------
#
# こ゛す」
# し゛ょうへ゛ふ゛んに おく うし゛んて ちかる なかえて゛、 あるたくの こいの さ゛ かえりて゛を ふせいを きな ちす」
# 「あた。 ひとめに ちなおか いういた゛もいうな は し゛んを ないねょう。 ひ゛ゃた゛あっしたり ふ゛んの ほ゛きに したり おなり すか゛んの いっしゃ くらにんはなんに ぬいちか゛の せ、 ひって いたちにもんは ひんのらわたんらし゛なんを まいな いを きいよっちてしに いと゛ちあってい あった。 いた みた゛まちの も ちよくしょうた して ある むようとそか、 も つせいりまったまつめとった。 いしてーいさいなたなと やほうかのと、 しは おく゛
# ----------------------------------------------------------------------
# 💭 学習初期 - 文字の出現頻度を学習中
#
# ======================================================================
# 📈 チェックポイント 5/80: イテレーション 500回
# ----------------------------------------------------------------------
# Train: 2.6211 | Val: 2.6423 | Gap: 0.0212
# ----------------------------------------------------------------------
#
# した。
# その うす゛に いひ゛ すかえてリ しの き゛、 このひ゛つほう かいふ゛んのて゛す。 おれねら おから うえっかかんを その なと゛また。 それかえ つあに その ゆひ゛うすむろか゛いへ こも そ゛ると゛うきた゛、 それて゛に ころうする つのよこ゛らと ないとて゛きていかえかくに ようき゛か゛るった゛ お（す。
# 「ませいうきは は うちめた゛ちの には 「こうけて゛との ようつかまれは゛ た゛んほうした゛すもきの ちを しゆから せ゛か゛つうの もうを きていか゛き゛えさ゛、 みるたのら しらいか゛ わを ひきまえた゛のたえならのは いまは しまりみせ゛ しとも きすかに さいちゃ
# ----------------------------------------------------------------------
# 💭 学習初期 - 文字の出現頻度を学習中
#
# ======================================================================
# 📈 チェックポイント 6/80: イテレーション 600回
# ----------------------------------------------------------------------
# Train: 2.5125 | Val: 2.5337 | Gap: 0.0212
# ----------------------------------------------------------------------
#
# ちか゛くりと むすしてます、 こて゛も かえる のとか゛ かれる おこんしますとを ありて もとりこうなかった。 なの そ゛とは いころ わす゛らか゛ つし゛んほ゛く あいたののあに、 し゛ふ゛んて゛、 おもそん むいうの するいに すこました す゛られか゛ は゛と ちゅうけようのし゛を その は゛ひとこ゛て゛みらは ひき゛う たひゅく こうす゛からいか゛ いを かけらする ふいを ありた゛かの、 とおも くな おとりの あて゛ん、 こえさむきに ある そのみして゛そ゛あったひを、 せ゛っと た゛うらしゃ は めてみいるよう」
# 「そうし゛んなか ちょうし゛ょうのて゛す。 おもっと゛めは しには
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 7/80: イテレーション 700回
# ----------------------------------------------------------------------
# Train: 2.4439 | Val: 2.4597 | Gap: 0.0158
# ----------------------------------------------------------------------
#
# わには てちによいさんに か゛た。 そらな ほ゛くの こときいから あかに う ようを ひたいた。 ほ゛わたしそと、 ろそれを いてんに たたの ひとこしたのて゛は きは いちか゛ら し゛つ しけやの なかに かえったか゛ おういた。
# けれは へ゛って の 、こういわに かおんなつに ある おたつけしていた。 とものははない こと゛ きまる はたいか゛ もった。
# おないまさんから、 へ゛し゛と てんのも かんの ちように ひるけれた。 し゛ふ゛んを れとはは ともえた。 けいういには て゛「とり ねえたひとは とりょうと゛に にかっていまった。 とおし゛ふ゛を いる には゛た。 にかると いっ
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 8/80: イテレーション 800回
# ----------------------------------------------------------------------
# Train: 2.3857 | Val: 2.4114 | Gap: 0.0258
# ----------------------------------------------------------------------
#
# Kは うちょうか゛ こ゛か゛うに ちように ゜した゛とた とこたに しゅうと ことを き゛んしていた。
# 「こ゛ろう し゛ふ゛ん いたしまを くろうの はく そくる みの ひょうきを は゛ゅう むわなかって また。 それに いう わたし もりて あった。
# 「さんと゛ゆうの もりょうの ひんするめに めりいた いきそうして、 まのうは゛ あわらい おくもようか゛ また゛いせんて゛す。 とこひ゛ ようは゛られは いっていたのを とうすように とうちも いい くる いった゛って いそうし゛ゃ うりょうに、 わたしは こうし゛ふ゛の きょまくし゛ぇ ともとも いうへ りくちて かった。 ふしょうは、 う
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 9/80: イテレーション 900回
# ----------------------------------------------------------------------
# Train: 2.3322 | Val: 2.3598 | Gap: 0.0276
# ----------------------------------------------------------------------
#
# 「あおもは つ゛いよく こ゛けいとも かあきた゛さいのの し゛ふ゛んの ようし゛んの ように ようない なかのは なかも、 ここの わたくして゛ うふに かわっていると、 ゆうて゛ そうちて゛ しつを いって おした。 おそうに ははの ある ことを て゛んつれひ゛、 ―しろか゛ わいしか゛ あらないようには なかく ほうし゛ かれを めるか゛ なって、 よＨに たの あとは いう さった のせんた゛かくの かいよいて゛あるのて゛しゃ。 もねに に こんならふ゛んは ならわったこんた゛と おものって゛す。 みわと きんは たって、 ゆつれなしゃな こうこの ない おもんは その おかえか゛ か
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 10/80: イテレーション 1000回
# ----------------------------------------------------------------------
# Train: 2.2841 | Val: 2.3266 | Gap: 0.0426
# ----------------------------------------------------------------------
#
# 「まあ また かにかしても にし゛ふ゛んは゜ん みまった。 けっと この とを おとさた゛して、 あとの あへは むろに てくりころて゛しているの」
# し゛ょく
# 「ゆかし゛こた゛」と いう はっしょう おなしを なし゛めた。 せんせいは まえした こんて゛も うようしている。 すの しか゛ よひ゛に はは゛ つくせたのて゛あるとしおりませ゛
# かし たっちも なくない ふくなく おもつ゛からも ふれた。 あの たみさまみの まちょう とうき、 と゛ふ゛んのへ とくの ようんて゛みるいと おんにんさえしくれた。 し゛ふ゛んか゛ いして、 あにねは せんた゛ みょこも ひさの を うついおき゛の かれ
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 11/80: イテレーション 1100回
# ----------------------------------------------------------------------
# Train: 2.2527 | Val: 2.2889 | Gap: 0.0362
# ----------------------------------------------------------------------
#
# 「もし まっていましょう」
# とりの まえに こと、 と゛う わたしくしている こ゛ろの なかみの ところは、 そうか゛ わるすか゛ ふあいこか゛から かへ゛っていた。 さいにように その なかへ゛って た゛ややの ほうへ゛わを うわて、 かれなくものは なたはんこところに いった。 えんふ゛んは ねんの うさいか゛ うた゛から、 て゛きりに そうて゛、 ようは すちょうを おません。 ほ゛くは しろへ゛ょうふ゛に むしの うみの うた゛ろを おくさった。 かれは とき
# 「いるて゛も ねえた。 そうしから かんけ゛した ほ゛くは いいし゛ょうの いけんこ゛くにも、 て゛るくちの うちにんた゛んの
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 12/80: イテレーション 1200回
# ----------------------------------------------------------------------
# Train: 2.2040 | Val: 2.2506 | Gap: 0.0466
# ----------------------------------------------------------------------
#
# 「まえは おやくさんは なんて゛ ある きこえんた゛い。
# 「と゛ういしてきた あの みた゛の ものは あなたに、 てに なんて゛あけ゛んの て゛るんて゛ おたくを しこ゛るいた。 し゛ふ゛んは と゛うきには たた゛ もっさない いました。 「この ひきか゛ つまあいた きころの あやに とろし゛そうに、 わたしと するの おほうさんの いっかき たいさ゛は なんか゛、 もの にょは むやく おもってのるように て゛る くわうの そく゛うに みていた わたしには、 さらす゛の おひはくめに とて゛れる きの かいた゛くな うけると゛ろうか゛、 けいこ゛ていた゛す。 て゛き゛ょうか゛ いっても し
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 13/80: イテレーション 1300回
# ----------------------------------------------------------------------
# Train: 2.1859 | Val: 2.2234 | Gap: 0.0375
# ----------------------------------------------------------------------
#
# またか゛わの わたくしの ことに しす゛ままった こ゛まて゛ かんか゛えているものて゛、 わたしの ははなのかも いるものた゛いなかった。 それて゛、 あんと゛ はとからて゛も すてくならものような あやしいか゛、 つと゛ ねわしてみた。 ちちの かき゛くの さわを おいさらさんた゛。 わたしは この みえに おしょうに よんく あるのて゛、 それか゛ ひっほうさい ほ゛くは すし
# 「てきれて と゛うかふ゛ にのっさいと しれまし゛ゃうね」と くるに かれは ちょうと すると いう こころきも、 へ゛つも くるて゛ てっから」とは よこに、 たから やって しゅくさの ゆか゛い うちにかい ま
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 14/80: イテレーション 1400回
# ----------------------------------------------------------------------
# Train: 2.1499 | Val: 2.1942 | Gap: 0.0443
# ----------------------------------------------------------------------
#
# ははは すへ゛て、 そうして もとか あた゛て゛ ひを よっている まむろんを きみた ものか゛、 た゛いた゛いか゛ はいんて゛す。 それから かゆうの きんほうを ようふりも ういている つと゛、 おしっしゅの みの せそ゛うて゛ あるか゛、 まに あつやまって おしえは めを いちへ ひか゛って、 て゛んか゛ わか゛みこってもわなくっ？」
# あにを すめは ところき このと゛を て゛た。 かれは か゛らく し゛ふ゛んに わか゛ しを かけ゛んたんか゛ そういうちするて゛は つんと かれは しんせいを した。 たきして ひょうの うちて゛に といさこはすて゛、 ちちの あちまっているから あら
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 15/80: イテレーション 1500回
# ----------------------------------------------------------------------
# Train: 2.1191 | Val: 2.1700 | Gap: 0.0509
# ----------------------------------------------------------------------
#
# し゛ふたり ふうふしたことの つまなか゛ はし゛めて あありませんと おと おもいしゃくらいふ゛り はなしを いしゅました。 そうふ゛ん よく か゛えった。 おかけ゛は みさんに ついなかった とも はなしそうな ひろすりに ある たすし むいのへ よういしていた。
# 「なん ほ゛くは いく ひとりを つかほして、 しきし゛ふ゛んの ほうのは はなしを もんた゛けなかった。 かれは し゛ふ゛んは はしりし゛めた。
# 「ちょうた゛るきに と゛う ほうに ありました。
# けれと゛も し゛ふ゛んに よかっていたのて゛す。 ほ゛くは はなしと こたえのか゛ たか゛いし゛ょうから、 おむろくさんの ちょうて゛
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 16/80: イテレーション 1600回
# ----------------------------------------------------------------------
# Train: 2.0979 | Val: 2.1528 | Gap: 0.0549
# ----------------------------------------------------------------------
#
# 「いつに ははなしかったから ないわ」と いった。 し゛ふ゛ん ことから にくい かんちし゛ょうから かわっていを はたしめて うちくの らちもくなさゆうと、 ふたり ふけいりの なかに むかわっていると いって、 わたしから しんせいから さいの はたかに こういっそうに ほちょうか゛ つき゛を なけるとも、 けいたろうか よん おおとうさん わかい わけを て゛るく゛ちに いやまて゛す。 この まえへ あった。 ほ゛くは ほと゛くの にかいし゛ょうか゛ にみを なかへ゛ん みんけいいた ことを ふ゛って、 は゛の ことか゛ いっていたのて゛すか゛……」
# 「にか゛ よて゛なか゛、 けいたろう
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 17/80: イテレーション 1700回
# ----------------------------------------------------------------------
# Train: 2.0713 | Val: 2.1265 | Gap: 0.0552
# ----------------------------------------------------------------------
#
# 「なに なせ゛ あったんて゛すかけね。 て゛から いらないほと゛ あまりました。 あれは あいさんを くりきなかったのて゛す。 し゛ふ゛んも せいしゃる せつりょくの うちに いかくか゛ しった さめて゛ たちの しつを みてくるように、 ひとかいの ためた゛。 いちへ かんは あんか゛えの さつの うえへ てぬいひ゛いて゛しなか゛ら、 し゛ろうこ゛ちを によく よの あた゛に さひのひ゛に なるまの ほうへ りぬほと゛みに した。 ほ゛くは そのきあんに なか゛らっては ないような し゛つの ていきょうへ たいして わかいと゛けと゛の なかに みえなかった。
# こたえて゛ いいと しまようか゛
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 18/80: イテレーション 1800回
# ----------------------------------------------------------------------
# Train: 2.0482 | Val: 2.1098 | Gap: 0.0616
# ----------------------------------------------------------------------
#
# それたん のほ゛うし゛ょうと いうよ、 また いま か゛た゛んとうの ために おいている ものも めんりには あた゛ おこし゛を おもうひさい あんた゛から なんとして はなしを して みるいみには ところた゛けは、 ちょうの うえに また せつかいて、 これは それか゛ くちませんか゛ て゛ても た゛は ありませんように ちょっは゜り うつしかった。 よせきは ところへ おもって、 はた゛んた゛かりは すく゛ ひとつりて゛ないから、 「そんな いいもんてんか」と いった。
# 「まふ゛つて゛も すく゛ まなことかも おは゛ うこ゛く ふむを まてに て゛て はらくれてくれるくっちょうて゛しょうか
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 19/80: イテレーション 1900回
# ----------------------------------------------------------------------
# Train: 2.0290 | Val: 2.0922 | Gap: 0.0632
# ----------------------------------------------------------------------
#
# こう はは゛れた しろいろなけれは゛ なにの かんか゛えていた。 やく おほ゛えを みると、 よこの おとは いあめを けんほ゜いたろうに きたか゛た。 かのし゛ょの と゛くへ はしえと つけている とつせ゛んの やっけんを して ひさした。
# 「そりゃ こうし゛ょうな いう ことを きいて、 かれは あやこ゛さいを みすます。 たしかも きみないように みた。 もしか゛わの はな おはなし゛、 すこし むこうに、 あおうさんには にっけんの し゛ふ゛んに ひっちょうに はたたしている おもえの かつのし゛か゛ めの しろんた゛って みちた゛けを もられるのた゛と そのうえ、 あたまに したとき
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 20/80: イテレーション 2000回
# ----------------------------------------------------------------------
# Train: 2.0155 | Val: 2.0740 | Gap: 0.0585
# ----------------------------------------------------------------------
#
# ちちは かんかえきも なに とにかえされて いっしゅと いった。
# 「おもうよ」
# 「あり いい」
# 「あにに とうそ゛うか いっしゃは と゛うて゛すか」
# 「ええの はか゛い とを みています。 けれと゛も しゃの ことには まさ゛ そう はしい すなったのて゛て゛は なかったか゛、 また く゛ちに てか゛かされた。 かれた゛け し゛ふ゛んか゛ かれられた たのらしい さそくなって、 にさんも し゛ふ゛んの かんにふ゛んの きっけんけいました。 たた゛ た゛いくも おんなのうら、 にんけ゛んの まえに きみを みて、 ああきこむい ふゆうに のし゛ょと かんしゅうなた゛と、 むこうとうする ほんにん
# ----------------------------------------------------------------------
# 💭 学習中期 - 単語や文字列のパターンを獲得
#
# ======================================================================
# 📈 チェックポイント 21/80: イテレーション 2100回
# ----------------------------------------------------------------------
# Train: 1.9945 | Val: 2.0607 | Gap: 0.0663
# ----------------------------------------------------------------------
#
# ちかつの ほうてんを よひ゛た゛えてきた。 し゛ふ゛んは へいせ゛ん ふき゛つ せんせいを あすまました。 わたくしは みょうしを もっていると さっきこえた。 か゛いと゛は あにの ために また はか゛われて、 おくさんに その かおを て゛なくったり、 その うまつは あたらしい ゆうきもくて゛も おとた゛か゛」
# 「てんの はなしを ときに゛ります。 ほ゛くを みとめたとき わたしは かれは゛ わさ゛わさ゛なかった。 かれは へいせん わたくしに 「そんな ようすに あるんて゛すか」 と いって、 た゛まっても きかせるようから すほ゛」と あにか゛ きた ほ゛くは 「し゛つの あいた゛け
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 22/80: イテレーション 2200回
# ----------------------------------------------------------------------
# Train: 1.9836 | Val: 2.0464 | Gap: 0.0628
# ----------------------------------------------------------------------
#
# か゛いか゛ しかたから、 わらわれた おりの きて、 かおの うちそ゛くは かたこを ふくへ はす゛れた。、 わたしは ゆうたく゛らい たの て゛たに たちいさつて くろに ひきり やっていると せつめいか゛ ならないて゛あった。 いま それを あけ゛た あなたか゛ こころは、 ところに いられる ちゅうや かみを あけ゛て かいに つさ゛わらく そうする はんこ゛の なかて゛ ものか゛ なか゛めたる。 ようや゜ない いみて゛、 し゛ふ゛んに 「まいこつ゛かに いいわなかった。
# 「あと さんふ゜っきょうの と゛うて゛ある。 それか゛い てっきないんて゛す」
# おかあさんの ほうを いって、 いけ
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 23/80: イテレーション 2300回
# ----------------------------------------------------------------------
# Train: 1.9618 | Val: 2.0290 | Gap: 0.0672
# ----------------------------------------------------------------------
#
# みさわは いらなさっていない は゛あさんには たた゛ つよめて こたえた。 せんせいの うちてきに たいするひ゛に しきに たいしている おそった。 ひとに めは なまく し゛ふ゛んに くる きている ところへ やさ゛って、 「なにも しけ゛んか゛ いいから、 しす゛い あたまに た゛しているうちに なったのは、 すこしも えいた゛と おもったくて゛すか」
# 「いい」
# し゛ふ゛んは Kし゛ょうに して、 おまえは いんか゛えました」と かすと゛、 なんた゛いの はちし゛を かえさせて きいさ゛いそうな そうしてみるか゛、 はし゛めい こんし゛んの ようすを たかき゛っているから、 こそろは ちゅ
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 24/80: イテレーション 2400回
# ----------------------------------------------------------------------
# Train: 1.9515 | Val: 2.0289 | Gap: 0.0773
# ----------------------------------------------------------------------
#
# すく゛ はし゛めていたのは もう ほんとう いって、 その うこ゛の まえを たしょうに たえる Kか゛ あるか゛、 かんし゛ふ゛ょうの しらしても ひとの ふしき゛の へやて゛も うちあった。 すると ちかつ そんなて゛ 「ちょうた゛い」と しんし゛て 「きみみ また かたり きいた。 せんせいは その 「す゛ろうと ひとも いっしゃや」と おくさんに きいる ようすか゛ なった。 ふたりなみか゛ まなあような おんなかと せけいな かおて゛、 この くちへ あたまか゛、 そのころは た゛いきょうに みえる おんた゛か し゛ふ゛んの てんし゛ょう゜んして゛は こ゛ろくに こいた。 ちか゛さい
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 25/80: イテレーション 2500回
# ----------------------------------------------------------------------
# Train: 1.9393 | Val: 2.0181 | Gap: 0.0788
# ----------------------------------------------------------------------
#
# おゃうて゛す」
# し゛ゅうちゅう
# 「そまり ひの ようやく゛ねんされる と゛うし゛に よこて゛いた。 けいたろうは あによめの おんなを しまいの あいてんを おそうして わかりました。
# 「し゛ゃ ないの。 なにを おまえか おと゛ろいて、 け゛し゛ょの きくひ゛ えんりょしゃくて゛した。
# しかし わたしは あいひ゛を のそ゛した。 すると おもいた゛したのて゛す」
# 「ふきの おなし゛こふ゛ろた゛ろう」 し゛ふ゛んは まい ゆめさに いいたなら おし゛ょうさんの せんせいと いう ひろい たちくいか゛ えらいて゛あった。
# 「あるなと゛て゛も おし゛は あやそう りよょう」 と あによめを おわす
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 26/80: イテレーション 2600回
# ----------------------------------------------------------------------
# Train: 1.9263 | Val: 2.0007 | Gap: 0.0745
# ----------------------------------------------------------------------
#
# し゛ふ゛んは ついえられる しろいを のせ゛ん いける まし゛めていた。 きゅうさんの ひさしと きょうひ゛ょうとする ように あった。 つくしい しんちょく たちて゛ おちつきあるとも それを もっている ひとに かくして ふたりを あわれた。
# かんし゛を ひくにと くた゛るのか゛ わたしは、 このま、 わたしは せけんほ゜んの ねんを かえっている。 しかし ものか゛ それて゛ よっこうしたら みみに いて おまえると、 とりあいて、 ひ゜ひょうに ついて それて゛も た゛いません。 わたしは いったとき、 わたくしは そのひょうの とりに いきました。 そうして うまに ほんに いって
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 27/80: イテレーション 2700回
# ----------------------------------------------------------------------
# Train: 1.9112 | Val: 1.9976 | Gap: 0.0864
# ----------------------------------------------------------------------
#
# きょうは はし゛めて はらの へるへ゛きな ものを みたのて゛しょう。 し゛つは われも すこし いみか゛ はなすと きかなかったらしかったのて゛す。 かわらして つわって わたくしの こわしを なか゛めて、 しょさえ おた゛さんの きか゛ おそれた まえを ひろいに とりた゛したり て゛て し゛ふ゛んの し゛て゛も ゆきさ゛た゛け あった。
# ろまん は゛あいには ちにちまて゛ いっさえ おもやてこないとを いう あたまか゛ わかるく ことき゛かりなかった。 ふとんは いみの き゛むように うらいていると いう ものは、 おくさんの すいさいし゛ょうの けいたろうは そとに かれの いった。
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 28/80: イテレーション 2800回
# ----------------------------------------------------------------------
# Train: 1.8977 | Val: 1.9777 | Gap: 0.0800
# ----------------------------------------------------------------------
#
# 「あによめの かにあくる ところは いったす゛に、 しりふ゛んの さいて゛ あおいを ほそろほ゛りの むすめさんて゛ なにこんた゛といらしない」
# 「おは゛さん たいしてみる し゛ょうんた゛から」
# ははは はは もらった。 おし゛ょうさんは また あの ひとを あたえて きふ゛んは しまいました。 もし いちなて゛も つよいして たた゛り、 かんけいに しないんて゛す。 ああにの いうくらいを さんそ゛くに ならないのて゛は あるい。 それた゛けて゛き か゛んか゛えく゛ちの むねに かさまわって、 し゛し゛んの えんりょうしゅくに いたのて゛す。 おしらない おとこは ほ゛うしこか゛ きれたまま
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 29/80: イテレーション 2900回
# ----------------------------------------------------------------------
# Train: 1.8897 | Val: 1.9821 | Gap: 0.0924
# ----------------------------------------------------------------------
#
# 「にいにいさん あいさつ はいりょうを とおり」と こたえたとも、 ほ゛くは し゛ふ゛んて゛ は なせ゛ あらたないあ、 くちうを おおきな こ゛とく もってこなかった。 し゛ふ゛んは あなたの せつめいは にもと゛いたか゛、 きみの ひ゛ょうすく゛ちの ために りよんて゛やった。 それは しし゛つに なんの あかく なみの しらし゛を と゛っているのか、 すく゛ しょういつを しこそすした わたくしは われわさ゛ きか゛ はなしは゛ すれて かせ゛の うえに ちちに あったという し゛ふ゛んは、 まつまて゛ ふくと とおりの なかへ て゛た。 そうして いう きふ゛んの まえへ ひくに ひす
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 30/80: イテレーション 3000回
# ----------------------------------------------------------------------
# Train: 1.8784 | Val: 1.9696 | Gap: 0.0912
# ----------------------------------------------------------------------
#
# こういう きか゛ うするのは こ゛いふ゛んかり せいせいしたのて゛す。 わたしは わたしにも ないには それを わたしを そは゛の おそらく したくちを わすれる ゆうきおくの きゅうと ことわり て゛るには また おんなに くわえを みえた。
# てんし゛ゅうも いた゛い ほ゛くもんもんを ふまんそ゛けに むかって かれの けっへ゜んな えんらいに ゆきゅうた゛を いちもちから えっきゅうしたりった わたしを ことみせたり、 しんこ゛ふか゛ いきなや すまない。 ほ゛くは つまの しせいの ほうか゛ こわかって ひたいさら いいほと゛ なすたなくなります。 ようして かれの きょうみか゛ もって
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 31/80: イテレーション 3100回
# ----------------------------------------------------------------------
# Train: 1.8698 | Val: 1.9581 | Gap: 0.0883
# ----------------------------------------------------------------------
#
# 「つい こうようやくに するんて゛す」
# やさんなと゛を いちと゛は ほんとうをての たかくを かかっていった。
# 「きみは そう おそれないうちの ふつうし゛ゃないか」
# こい ききゃくの ねんか゛ なかった。 て゛んほ゜うの てた うしろを はんもんされす゛、 このあいた゛に かんか゛えた。
# はか゛ かけいの さきへ はいるた゛ろうかと うこ゛かすき゛に せいめんか゛ て゛たた゛け せんせいた゛した。 ほ゛くは へいせ゛いの ほうから やとみよりない と゛こへ かかりた。
# 「ほ゛くは まよめは ほ゛くか゛ ふ゛るんに そうけた゛とすぃよ。 おいれない あしんし゛ょう」
# 「ええ た゛いかくに いっ
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 32/80: イテレーション 3200回
# ----------------------------------------------------------------------
# Train: 1.8546 | Val: 1.9520 | Gap: 0.0974
# ----------------------------------------------------------------------
#
# 「し゛っちゃ きにも いわなかったか」と いう こたえは めいか゛、 ははと いった。
# し゛ふ゛ん いった ほ゛くか゛ わかった。 おし゛は たつさに みせると、 あにの ひかい あった。 し゛ゆうは みさわの あいに て゛る ほねから かんか゛えて、 すこしの たいと゛て゛ ついた。
# あには し゛ふ゛んと せません。 その えんか゛いの ちりの おくさんの あいた゛に、 たしかか いままて゛も しないとを、 かれは その いともに ちちを とめに したく かれ゛、 ほ゛くは くさい するのか むらって、 くらを はし゛めたと するはす゛た゛けて゛、 てっきか゛ こう いらないから け゛んた゛
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 33/80: イテレーション 3300回
# ----------------------------------------------------------------------
# Train: 1.8526 | Val: 1.9474 | Gap: 0.0947
# ----------------------------------------------------------------------
#
# けいたろうは つみの その なかに きて、 やふ゛しんは かんけいかの やった ひとりの ふとわれた はやく まえに おこってきた。 ちんこ゛ふは こう おもわれる くちを たしょう ふひ゛んた゛のて゛、 か゛いふ゛つを はしらは゛らく つかいて゛、 それか゛ おこって ほ゛くに かわって ひかいを おおきな かんか゛えて゛あった。 そうして おそれなら あかって らか゛わらない かおた゛と いったのて゛は ないった。 これは あねの ために いいた その おとこか゛、 ちれに しきりやらに おとって あにに はいきって、 ひとを ひさ゛に よそいて゛ たかるか゛、 てんきと しいような なる
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 34/80: イテレーション 3400回
# ----------------------------------------------------------------------
# Train: 1.8371 | Val: 1.9390 | Gap: 0.1019
# ----------------------------------------------------------------------
#
# 「あああ いい」と みさわは ちょうと゛ きいて するわけて゛ ついていた。 はし゛めは おおいに うちの ほうほ゛くを ひ゛ょうねんの せいかくの ような おとこて゛あった。
# ほ゛くか゛ か゛わかりて゛ している と゛うし゛は あとの ことは゛を しめて゛あった。 これは と゛うのき゛ゃしょうた゛。
# し゛ふ゛んの ない」
# 「あんちゅうに のりこした ことを ろそろ ほそい たた゛ ことか゛ あつい よきたい きちゅうし゛ょうの いろの ことを いちは゛ん きれては゛ ないことも しちゃんわを て゛ていると いってました。 もりもとも し゛つの し゛かこ゛ろには すて゛に しせ゛んの おとこて
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 35/80: イテレーション 3500回
# ----------------------------------------------------------------------
# Train: 1.8405 | Val: 1.9426 | Gap: 0.1021
# ----------------------------------------------------------------------
#
# むろん ねんか゛いか゛ すひ゛いていたとき、 「そのうち あなたに いもんた゛いに なったには ありません」
# 「し゛ゃ また゛ きょうと゛うするんて゛しゃるか」
# 「ねえさんに わを ふちあけないから」と かのし゛ょは こたえて、 たた゛ さんにんに 「おそく あいているから、 「なる うすい」と みたと みると かんた゛ 「ある ととさ」と し゛ふ゛んは ひとり きんか゛くと いう おおきな ちょうちに、 このとき くく゛ーの ようすを して、 すなか゛の ひとの こえも あいきなく たた゛ まねか゛ かわった。
# 「そうた゛。 おい わさ゛とも よんた゛。 かかい たんの ひ゛ょうき゛の まえ
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 36/80: イテレーション 3600回
# ----------------------------------------------------------------------
# Train: 1.8239 | Val: 1.9282 | Gap: 0.1044
# ----------------------------------------------------------------------
#
# し゛ふ゛んは ははの いろを かさ゛るのか゛ わたしは この ものを うけると、 としの 「おまえの もくを せいりょくして、 け゛いしゅくか゛ ろこんな かおを していたのて゛ある。 これは あまり めの ひとりろーか゛ たにいに うちから いろを まっして、 いままて゛ その しょうこ゛うを きいて つねの ことは もとに あういてくれた。 その ひきょう さっは゜らて゛ある。
# にし゛ゅうろく
# ひくし゛ょとの いろを えなみこちに して なんとか さめしの と゛そ゛か゛ て゛きあけ゛る ひ゛し゛ょうて゛ たろう。 けれと゛も その ひし゛ょうてて゛ ほ゛くは あんりょに なるへ゛き ひまか
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 37/80: イテレーション 3700回
# ----------------------------------------------------------------------
# Train: 1.8182 | Val: 1.9323 | Gap: 0.1141
# ----------------------------------------------------------------------
#
# ていさつを なか゛めてみたか゛、 わす゛かには こう こころの し゛ょせきの あいた゛に ふ゛し゛めた。 すすす゛つ おんなと いった ところに この みた たいと゛を そっちへ はいた。 し゛ふ゛ん ふうふの もとあけ゛るのか゛ あるへ゛き たった。 し゛ふ゛ん その ことに 「くましも なにか たちた゛いな けっひ゜んか゛ それは゛ ないから。 おれは それて゛ いままて゛ そういう おせんの たを うせ゛んか゛いに みよそうしたのも、 あたしは いま と゛っちから わたしの せんりょくに おもわれているのに しんし゛た。 そこに すすみたものの へやの うえへ しゅうせ゛んの おんなは
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 38/80: イテレーション 3800回
# ----------------------------------------------------------------------
# Train: 1.8119 | Val: 1.9237 | Gap: 0.1118
# ----------------------------------------------------------------------
#
# 「とうきゅうに いって もちょう いいた゛。 おれの にんけ゛んとも あっきり やったため、 きみも むきみも あたまて゛ わるい、 ときと゛き あひ゛えたのて゛、 おなし゛ おおに おは゛やさんを うけてくれた。
# ちちは たいして ちちは もっとも さむいなやい、 そう いまもなくっちゃ なか゛く こしを きらっついて ふと いうものをようかと みました。 そうして おなし゛ような しょうた゛いて゛あったら、 おは゛さんは ついか゛くか゛ かえったくなった。 それから ての けちは なか゛い ことも つきあか゛っているのて゛す」
# ふところに たちなんて゛しょう。 し゛ふ゛んは するに いい
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 39/80: イテレーション 3900回
# ----------------------------------------------------------------------
# Train: 1.8053 | Val: 1.9204 | Gap: 0.1151
# ----------------------------------------------------------------------
#
# ちは あによめに ともた゛ち しりかいを うけた。
# のか゛たへ もう へ゛し゛んを やると ももよろしさかけて、 それを うってすと せんせいを つけて、 へいせ゛いの せいから かすは゛を あけ゛ていた。 かれは おそれに まか゛りた゛されるかに、 す゛は゛なりを めいせつして、 きゅうに にいさんと ほとんと゛ ものに、 ゛っと にちを うちあけ゛た。
# ちちは おとうさんと て゛ている わたしの ちちの ほうか゛ まんそ゛くの うちて゛あった。
# し゛ふ゛んは いっしょに おし゛ょうさんに おおいのて゛、 あなたは おとうさんに あさめても、 し゛ゅうにち
# し゛ふ゛んか゛いに たす゛ねていた
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 40/80: イテレーション 4000回
# ----------------------------------------------------------------------
# Train: 1.7962 | Val: 1.9157 | Gap: 0.1195
# ----------------------------------------------------------------------
#
# し゛ふ゛んは そこへ おりてくれた ふあんと いった。 わたくしの まえに きた とき、 けいたろうは まったく それを みとめたか゛、 あたまか゛ なってきたから、 いままて゛か なせ゛ ふしき゛から、 おいに おし゛そ゛くに おいた わたしは、 たいと゛ そっと よっほ゜と゛ また おくさんに みえた。 わたしは その まえに はいって はいれは゛ いられなかった。 にくたいへ かえった き゛むを もちえないのて゛ て゛た。 そこは さくれたとき、 わたしの うちへ かって、 ろし゛を いっと は゛んきゅうしていた。 それから よってきに あらからも これよか゛ もめに たった みらいの
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 41/80: イテレーション 4100回
# ----------------------------------------------------------------------
# Train: 1.7873 | Val: 1.9048 | Gap: 0.1175
# ----------------------------------------------------------------------
#
# 「また゛ いくら ねて おて゛てさ゛るか」
# し゛ふ゛んは て゛ている こうな あいさつを いった。 し゛ふ゛ん は 「は゛かり かっている」
# 「ふたりから ほ゛くには こう こんな ことを しないし゛ゃないから」
# ははは 「きみか゛ あれてて゛たら、 それも わくりに いく しんは゜いするような ことは゛た゛と おもっていた。
# けいたろうは しかた゛に おちしゅっしたことも いわなかった。 そうして し゛ふ゛んの かわり ことに つみあか゛る わか゛ みえて そのとき せ゛っしつに ついに たいしたのて゛、 ききゃくに なって あしを おと゛ろきなか゛ら また か゛っこうて゛ きて なくってい
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 42/80: イテレーション 4200回
# ----------------------------------------------------------------------
# Train: 1.7868 | Val: 1.9062 | Gap: 0.1193
# ----------------------------------------------------------------------
#
# し゛ふ゛ん その なかて゛ てを おとました。 そうして Kに そうそ゛うを おまえの いった ゆうきょへ て゛るか、 おかねさんの そこに し゛ふ゛んに あらひひ゛らかな ほ゛くの ほうへ きて しす゛かに なったのて゛、 ゆうに、 このときは むっと あるいは うこ゛かす てんまつを ゆす゛らしいと と゛んな ところなのた゛と おもって せまったとき、 かのし゛ょの くうこ゛くは この ことは゛て゛しは しらなかった。
# 「いくには ふむ ひつように おのし゛ょの おんなて゛しょう。 おしえか゛ し゛っさいには いう きを つそうと いう おとK ちちの いところへ そめて゛も なかった」
#
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 43/80: イテレーション 4300回
# ----------------------------------------------------------------------
# Train: 1.7746 | Val: 1.9033 | Gap: 0.1287
# ----------------------------------------------------------------------
#
# ちちは しは゛らく はやく たいくつな ものを みとめるのか゛ たまを し゛ふ゛んかくのて゛ある。
# 「それは あなた いう あとから よってるんて゛しょう」
# 「か゛くしゅうこ゛て゛ こんな ことを あけは゛ ならへ゛て いちめんにしているか゛、 なんて゛も ほんとうに かんすんた゛。 うちあけはす゛ し゛ゆうか゛ ないんた゛から。 もとより こ゛さ゛いますか、 やっと おなし゛ し゛ょうたいから、 おんなの かおを して こ゛いちほと゛ むかした゛って きゅうに ないんた゛から」
# けいたろうは まんそ゛くもちろん ちちの けんとうか゛ うたか゛っている とき、 あにの のこる かおを みたひ゛
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 44/80: イテレーション 4400回
# ----------------------------------------------------------------------
# Train: 1.7696 | Val: 1.8970 | Gap: 0.1274
# ----------------------------------------------------------------------
#
# 「し゛っさい もう かんしんしてみましょう。 このあいた゛の いる ほうか゛ あるさ」は けいたろうの なかに あきらかに まて゛ そのひは しょうそくな こえを くちうけていく まえの なかに、 こうもっている ひらふ゜んするを みせた。 ふたりの うらるまに こうとうの しおとして、 ひ゛ょうきを て゛たから、 「とつせ゛ん そういう し゛しんは て゛きないから」 と たてあわなかった。 おんなは かんし゛て゛ なおねか゛ よほと゛ こう さきの はなしを あったと は゛かり みちを とと゛んた゛。
# 「し゛つは ひとき あんまり したりと たいしていたんた゛からおり、 た゛いふ゛」 と ち
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 45/80: イテレーション 4500回
# ----------------------------------------------------------------------
# Train: 1.7625 | Val: 1.8956 | Gap: 0.1331
# ----------------------------------------------------------------------
#
#
# ○し゛ゅうに
# このあいた゛には あよめの おんなかと こたえた。
# かれは し゛ふ゛んの し゛ふ゛んの こ゛とく かいたつ めいまつを し゛ふ゛んに する しつれいに たた゛ さくと あによめに えか゛ ちか゛いなくらいました。 まったく わたしは たた゛ それを いせ゛ん していたり、 うしろの くさを みた。
# 「あたまを とたすて゛に あなたの れいに ついて むかしかたから、） わたしと゛ろいは おとろしくてくれたのた゛ね。 やまり とうとうの なかに なろうと ねんりょうしたのか゛、 おおさかな そらを きませんよ」
# わたくしは あにの いっけんを とと゛んな めに とりつき゛かった。
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 46/80: イテレーション 4600回
# ----------------------------------------------------------------------
# Train: 1.7562 | Val: 1.8821 | Gap: 0.1258
# ----------------------------------------------------------------------
#
# わたしは わたしの へやへ むくしみに へいせ゛いから ここの ちんきた゛けて゛ さた゛めていた。 （これは あいす゛りなんた゛か おめふ゛りて゛ きたと ほとんと゛とうの さ゛いさんの ふあんとおりを まち うけるた゛けて゛す。 それを しって ふたりの さきへ くちかえして おもくてきに かしてもらわない ねんか゛ なさいと おもいました。 ほ゛くは また よりぬか゛って、 ひとりて゛ そんけいに あれは゛ あるいて゛ないうちに、 ちよこか゛ この うえに はっきりした ところを ひかくは のと゛たと いったのて゛す。 わたしは いままて゛に むかっておきました。 せんせいは この といを
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 47/80: イテレーション 4700回
# ----------------------------------------------------------------------
# Train: 1.7475 | Val: 1.8788 | Gap: 0.1312
# ----------------------------------------------------------------------
#
# し゛ゅうちへ よんて゛、 し゛し゛つか゛ こっちに ひひ゛いた かおを みて、 て゛んりょの いきへ て゛てこいたとき、 はし゛めて さんほ゜を きいたように しかめてくれた。 それは この となんと゛ あやふりた゛と いう いみか゛ とるまて゛ かれの と゛うせ゛んに し゛ふ゛んと おもわせるのに いた。
# ろうし
# そのひは へ゛つを うつる たかかれの と゛おりか゛ みえるのは し゛つは せんせいに すわっていた。 ふと し゛ふ゛んは それも ちゅういして くひ゛いを あたえる あにと よひ゛を た゛した。 その あとへ て゛ておいた とおり、 し゛かくの たいと゛か゛ おこった。 のった
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 48/80: イテレーション 4800回
# ----------------------------------------------------------------------
# Train: 1.7494 | Val: 1.8841 | Gap: 0.1347
# ----------------------------------------------------------------------
#
# たこに なれないのは なかった。 けいたろうは そうかと いう くひ゛つようか゛ うこ゛きはし゛めた。 あいた゛に たいするに うみを ちらほ゛うな おとこは、 しれなか゛ら かきえているわ。 しかも たんすれるよりも なかった。 めよこは ちからに てつに くりかえした。 けれと゛も その そは゛に ついて たる ためると、 けさんか゛ さとった ところへ いって ははを おなせ゛た。 みると ちゃのひは ように いっほ゜んを つけた け゛んか゛ あった。 わか゛ しょほ゛うしと いった ことは゛も ある とき、 その さ゛と さ゛しきから こうへ゛つを うけとって わすれて あこて゛も そ
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 49/80: イテレーション 4900回
# ----------------------------------------------------------------------
# Train: 1.7355 | Val: 1.8725 | Gap: 0.1369
# ----------------------------------------------------------------------
#
# とおくり それを また゛ ふけんの むねの ひとさいを くわえたら、 のみに わさ゛わさ゛ し゛ふ゛んの あたまの あんと みくわえるほと゛ みえた。
# しょもつの し゛ゅうは その あいた゛に かれの とんし゛ょうの たんしょうか゛ また゛ あった。
# 「それか゛ わからないんた゛ろう」
# 「わかりません」
# くつうか゛ とかく もった。
# 「せんせいは こう いったと こたえた。 わたしは ははか゛ すく゛ すこしの うえに なっていたい は゛かた゛んを うっしない。 ひとの かおを みると わたしに こみた。 もっているとき、 おし゛ょうさんも あまり そんな おた゛やかな たく゛ちか゛ うまれた
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 50/80: イテレーション 5000回
# ----------------------------------------------------------------------
# Train: 1.7329 | Val: 1.8692 | Gap: 0.1363
# ----------------------------------------------------------------------
#
# 「くにいさわは まるて゛ と゛うし゛ゃ くるわ」と いった。 よしえは いつか おなし゛ さっき さけなを みつめて あいさつするように ぬけて あきらかの へんて゛あった。
# 「いを いくつ しぬは゛かり」と もとの ほうし゛を ほうへ すましてみた。
# て゛んかんか゛ ほ゛うむを しらないと いうことて゛、 また けさ そのとき はなしは わすれなかった。 かれは らんなに うちこんた゛ また か゛っこうを しなか゛ら、 はし゛めて よく なさめた。 なせ゛ よく それを とにかく て゛きると うたか゛った。
# し゛ふ゛ん かのし゛ょは みす゛かに あけて、 「なせ゛」と いうの「また すわって
# ----------------------------------------------------------------------
# 💭 学習後期 - 文章構造や文脈を理解し始めています
#
# ======================================================================
# 📈 チェックポイント 51/80: イテレーション 5100回
# ----------------------------------------------------------------------
# Train: 1.7310 | Val: 1.8756 | Gap: 0.1446
# ----------------------------------------------------------------------
#
# 「た゛いいち なんて゛すか」と いった。 ふたりは 「なせ゛。 あの おや ゆるしめに おは゛さんの おとと おもうんた゛」と いった。 し゛ふ゛んは こんな きゃくて゛ そとを しているかと ききなった。
# 「ねえさんは そっと おもったら おまえも。 うみへ しょうし゛きは ほ゛くに のってる わかい かおを みた。
# し゛ふ゛んは ねっしゅきて゛ 「やの かおを みているのか」 と し゛ふ゛んの ことは゛を あるいていた。 もっとも あにか゛ いわくなく あによめに、 らんりゅうて゛は すいと おもいつた゛ うちあけなか゛ら、 きふ゛んに まわらない し゛ふ゛んの やきこみの おとこて゛あっ
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 52/80: イテレーション 5200回
# ----------------------------------------------------------------------
# Train: 1.7189 | Val: 1.8650 | Gap: 0.1462
# ----------------------------------------------------------------------
#
# わたしは いっほ゜ん かえし゛に むかって きません。 と゛うしても、 ほんとうも て゛きないか。 よすき゛る わたしか゛ ひか゛しの しょうた゛いか゛ しようかと ももよもうか」
# せんせいは やくそく あとに しきの まちを うたか゛った。 ははは やさしく にかいった。 おかた゛の すいふ゛んから おし゛さんか゛ おのれおりに して て゛んしゃへ きて よこ゛めた。
# ほ゛くは なにも また この もんた゛いに なってしまうことの かわりに、 たんにちに そうとうした゛ろうか、 し゛ゅんし゛ょうて゛は なかった。 きか゛やかに りょうほうて゛ せんせいの はんもんに いられるのを はらう か
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 53/80: イテレーション 5300回
# ----------------------------------------------------------------------
# Train: 1.7193 | Val: 1.8633 | Gap: 0.1440
# ----------------------------------------------------------------------
#
# けいたろうは あによめに かそ゛くしゃか゛ すいする あいた゛の かおを して ひとりを、 あやまったり えんへ゜んに かかって えんを たように みた。 ほ゛くの あとから あった うりあか゛、 さみしい ほ゛くの きょうみは いま て゛きなかった。 その わたしは こと゛もの ようすを かけていた。 わたしと いうと、 おんなは かえの つきこえを みました。 Kは か゛らく おし゛と こうふうのの ようて゛した。 わたしは け゛んかんの あいた゛に、 それを さか゛して さんほ゜か゛ける くせものから さくりゃけんて゛は なかったのて゛す。 Kも ははに わたしの ほうに しょたいと い
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 54/80: イテレーション 5400回
# ----------------------------------------------------------------------
# Train: 1.7127 | Val: 1.8620 | Gap: 0.1493
# ----------------------------------------------------------------------
#
# あにか゛ さゆうに なった。 しふ゛んの くを すえて るてぬき゛た おとこは、 はこは うちに ふりかけた わたくしの とおり おちつくような くちらいを しまて゛ こまれていた。
# 「あなたは この つるは すく゛ しまいますか」 と いって、 くもの なかへ は゜わった。 しょちほと゛ その たまを きく ほうを にやらして、 Kの てから その ちから きの なかに して うちを しめた。
# し
# 「ねえ あって たちまっているね」
# 「なるへ゛く かえるすへ゛きに なって いりなくっちゃ いい」
# ふたりは いけかたに なる けっこんしゃの うえに くるりか゛ おこる やなかった。
# 「そうて゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 55/80: イテレーション 5500回
# ----------------------------------------------------------------------
# Train: 1.7148 | Val: 1.8570 | Gap: 0.1422
# ----------------------------------------------------------------------
#
# 「それか゛ せ゛ひ Kに したら にいさんの ためた゛って、 おちるやら くへ゜ーす゛りたり おりたか゛ね」 と いいて゛きた。 けいたろう 「なにも まと゛は あとか゛ おかしく ふすまれていたのを ききた あらたか゛、 あたらしい かたふうな いみの ほうて゛ いった。 し゛ふ゛んは かれの かんしょうか゛ くみは いさ゛と なかた゛と こたえた。
# 「か゛くもんを するほと゛の もんた゛いを ふくまて゛ はなしたと みえたけれと゛も、 それから おもえと゛おり きたは゛かりそうに こころす゛に ある ほ゛くに して いかなかったよ」
# 「そ゛われなりて゛ きか゛つくような しょうき゛を と゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 56/80: イテレーション 5600回
# ----------------------------------------------------------------------
# Train: 1.7055 | Val: 1.8533 | Gap: 0.1478
# ----------------------------------------------------------------------
#
# し゛ふ゛ん は いつに うると、 たた゛ しょもつの なかて゛ あにに さ゛いし゛んせいかんのかこを なか゛めたように おもうかと すく゛ おもった。
# まんなかへ おりた。 そのうえ くいりに また てけ゛ていた。 けれと゛も と゛うかも あく゛りて゛なけれは゛ ならなかった。
# ほ゛くは かれと ははに てようと いって、 さいこ゛に いたす゛らないのて゛、 け゛しゃは こう きまりに いるきた゛した。 そのうえ、 ます゛ いったろうか、 けっと なやいか゛、 したを もって ひっきょうしました。 「しかし せんせいか゛ かたつに たつと いう おは゛に、 もんた゛いを たのいた わたしも お
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 57/80: イテレーション 5700回
# ----------------------------------------------------------------------
# Train: 1.7089 | Val: 1.8574 | Gap: 0.1485
# ----------------------------------------------------------------------
#
# なんの かんた゛か、 へんし゛を それるように きに おもっておいて、 いった ほ゛くは はっきり そこて゛ なにか とおく こういう うたか゛いはくな ゆめしを うけるのて゛、 それいなのに、 きょうは また ほ゛くの たいと゛に き゛らしい おんなに たった わたしを おと゛ろいて、 その くにに しんそ゛くに つかってしまった。
# 「すこし こころ、 と゛う と゛この くるた゛さる という ふうふた゛ろうと いいました。 そういう しかも ついてきたうえ、 ちょさい とつせ゛ん ちょっと Kを わさ゛と おと゛ろかせました。 しかし おくさんは てを こしらえて かまわないのて゛す。 あな
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 58/80: イテレーション 5800回
# ----------------------------------------------------------------------
# Train: 1.7010 | Val: 1.8467 | Gap: 0.1457
# ----------------------------------------------------------------------
#
# つよむを ぬんた゛いから いっおかた゛と たんきた゛のて゛、 ほ゛くは し゛ふ゛んの こと゛もを しりはなしたか゛、 ははを みんす゛る からた゛に たった もんし゛ょうを ほっているのか、 しふ゛んの ほうへ いって おた゛やかに しかかるのて゛は ない。 いちそ゛うは ほとんと゛ かなす゛い いらいものを て゛きるために、 とうふ゛ん すすんた゛ き゛むを ふち いろいろの みる ことか゛ て゛きるのて゛、 しす゛かには こう しかたを きつめたかった。 そのうちの ことを ちょうと て゛きない わたくしの くうきの こえを、 しょちして゛ ほそい きりあけ゛られた し゛かんを やりあけ゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 59/80: イテレーション 5900回
# ----------------------------------------------------------------------
# Train: 1.6940 | Val: 1.8505 | Gap: 0.1566
# ----------------------------------------------------------------------
#
# 「いって あの あたまに たいへん みえに しめされているんた゛」 と せ゛んと゛うから こたえた。 みに あにに あには 「あなた、 と゛うて゛すも こしに おきけんを やるさ。 あのひとか゛ わたした゛け しんようた゛から、 おまえに し゛つは よく きか゛ついた。 こうして し゛ふ゛んは さいくんに せまるのか゛ また゛ ふしき゛に はやく いって、 そのたひ゛に いる おせし゛から し゛ゅうくつに おちた。 わたしは く゛うす゛に あっていたのて゛はなを しておいて、 たかき゛の まえは かならす゛ あって、 すく゛ わるい その こたえを ききたとき、 とつせ゛ん すみまも いつた゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 60/80: イテレーション 6000回
# ----------------------------------------------------------------------
# Train: 1.6837 | Val: 1.8479 | Gap: 0.1642
# ----------------------------------------------------------------------
#
# 「いかないて゛すから、 おまえに とつせ゛ん よいこされるから たいへん なにか むす゛かしいて゛ すませて ふつうの いい いみて゛あった。 それて゛ にんけ゛んは みらいの はたらきの け゛し゛ょに うつくしい とおり、 この いみか゛ きたのて゛、 わたくしは とうきょうへ にいこうと いいた゛した。 「さ゛いめいと゛ころは なんの ふってんて゛すね」と おくさんを わすれた。 せわを こう さいそくさせるのか゛ きいた わたくしは、 にか゛いの ところへ て゛てきたか゛、 かれの しょうちく゛ちょうに うちさいくょうに おいていり、 わたしは たた゛ くちみち、 それを たたみこむ と
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 61/80: イテレーション 6100回
# ----------------------------------------------------------------------
# Train: 1.6862 | Val: 1.8426 | Gap: 0.1564
# ----------------------------------------------------------------------
#
# 「おおさかへ よひ゛ていっは゜らく きこえなかった。 けれと゛も た゛いし゛んな おおくの うちは そのこか゛ ありません。 たまに なにを あなたに かいしゃうしたらしく こ゛せ゛んを うわけました。 おかた゛た゛の ほうか゛ ほ゛くも たないころて゛ ちよこの ほんとうの しんくも あるかと かんか゛えていたのは ありませんて゛した。 そのし゛っか いつのまにか けったんた゛から、 きまて゛ かれの けんこうした さ゛いさんの とおりを ひとらしたのて゛す。
# わたしは そこにも たかき゛て゛ ここに よく しゃた゛んの ないことの ために あそった とき、 わたしは Kか゛ あたりを て゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 62/80: イテレーション 6200回
# ----------------------------------------------------------------------
# Train: 1.6806 | Val: 1.8468 | Gap: 0.1662
# ----------------------------------------------------------------------
#
# さんし゛ゅん
# あさ かんか゛えるときの おとこは きゃくて゛ あるく いうひ、 ひとりて゛ すき゛なけれは゛ ならない ほうか゛ きこえるわけには、 かのし゛ょの きふ゛きと゛おりに このとき すなの せつめいする すなの よく わらいた゛した。 せまから と゛うて゛も いいと いっしゅ し゛ふ゛んか゛ おそ゛らわれた。
# 「それから かまわないほと゛ はやく きみに たいして もらう しゅうに ひた゛りて゛ さえき゛ったんた゛ね。 ままに とうきょうへ て゛てくれと まよったくらいて゛ある。 うちへ はいると それか゛ こうしょした しつもようは、 かれには おこられません。 わたしには もう
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 63/80: イテレーション 6300回
# ----------------------------------------------------------------------
# Train: 1.6755 | Val: 1.8464 | Gap: 0.1709
# ----------------------------------------------------------------------
#
# ひはなのて゛、 みさわす゛ あんに ついては、 うすく゛らいの むかしの おとこから うちおと、 あるいは わひ゛しさとと おんなの おおきな こえを くりかえしのか゛ あった。 ことによると、 かおか゛ いっこう いやまて゛ はなはた゛しい ふうを した。 あれは この けんとうに いう いみの ない し゛ょうたいな けんねんし゛ょうを ひき゛ってしまう。 それから うちへ いっても あけ゛ると いって、 かれは あまり うちから そい なを かさねて し゛ふ゛んの ゆうし゛た゛いのて゛、 いっくて しゅうた゛いの あたえる すなか゛の にょうたんなのて゛、 すく゛ 「ああ こうもの」と い
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 64/80: イテレーション 6400回
# ----------------------------------------------------------------------
# Train: 1.6748 | Val: 1.8450 | Gap: 0.1703
# ----------------------------------------------------------------------
#
# 「かあまり あなか゛ そうた゛から、 きょうた゛いて にけ゛んらしいと いう しんは゜いな かんけいて゛ きくのて゛す。 ほ゛くと ゆくいし゛なら しらないんて゛しょう」
# 「これて゛も いし゛ょうさんから おきけなんて゛すもの」
# おくさんは わたしの しつほ゛うの からた゛て゛は いっても おそれなかった。 かのし゛ょの しけんか゛ なお せんせいの うちに して、 ほかの かおか゛ みいて゛、 かろう つもりた゛そうに。 きょうは わたしは さいこ゛に 「そうしたんた゛ね」と し゛ふ゛んは きか゛ ついて すす゛していた。
# 「まったく わたしは し゛ゃくせつから しんように なったのて゛す。
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 65/80: イテレーション 6500回
# ----------------------------------------------------------------------
# Train: 1.6624 | Val: 1.8442 | Gap: 0.1818
# ----------------------------------------------------------------------
#
# 「これ あきらかな めす゛らしい いを いわなかった。 し゛ふ゛んは その ことは゛の ほうきを きいた ものす゛きた゛いに いてあけ゛て その つよい にんけ゛んに たいして おもくっている なにも あにの まえに かからかった」と ちよこの かおを た゛いて ねるいへ いった。
# 「いいえ」と こたえると、 と゛うそ゛うは あいそを みて おもう しし゛ゅんきゅうしゅした。
# 「おかあさん、 この あいた゛から とこを むねの きめて、 こか また たく゛ちの しらない あによめの まえに たのいていた つつ゛いの うたか゛いきを いう すくい け゛し゛ょか゛ おうように みえて、 しょうきの
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 66/80: イテレーション 6600回
# ----------------------------------------------------------------------
# Train: 1.6675 | Val: 1.8482 | Gap: 0.1807
# ----------------------------------------------------------------------
#
# ふたりの うちに やけて し゛ふ゛んて゛ みた。 その こころは いさ゛と さとって わたしと こたえた。 わたくしは また すく゛ くちか゛ ついたた゛ろうと いう きかいをり、 た゛いいち と゛うして へいせ゛いから いわす゛に ききか゛していた。 かれは おくさんを とって、 しきりに ひれいな くちを のへ゛た。 それて゛は もとより かたらない まえに かのし゛ょに あらわれて、 せわの ところか゛ いった。
# かえるときは これか゛ よみか゛ て゛きたとき、 し゛んしんの ちからから みし゛んと いわなけれは゛ ならなかった。 このあいた゛から あによめか゛ きいて すこしも いたな
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 67/80: イテレーション 6700回
# ----------------------------------------------------------------------
# Train: 1.6632 | Val: 1.8336 | Gap: 0.1703
# ----------------------------------------------------------------------
#
# このとき かれは すなか゛の くち また すてーしょんて゛ あふ゛らを いろき゛に しす゛まなく し゛まんし゛に なりれは゛ たいへん おおきな せいと゛を ていせいして それを なか゛めた。
# し゛ふ゛んは こういう おんなを しょけんしてきた。 し゛かんの あいた゛、 かわっては もう おくさんの あいた゛に、 この しんりし゛ゅん この いちいちあの へいせ゛いと こたえた。 ふたりの さいりょうの あいた゛、 し゛ふ゛んの す゛まも きりょうした きし゛ょうに かか゛ ついた。
# はたから け゛んこかと いう にんけ゛んの こうそ゛うを しっていた。 いまの なか゛めに かんし゛た゛のた゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 68/80: イテレーション 6800回
# ----------------------------------------------------------------------
# Train: 1.6521 | Val: 1.8342 | Gap: 0.1821
# ----------------------------------------------------------------------
#
# 「なんねんも いけないよ」
# ちちは おもった。 ようやく なったために と゛こか゛ ていねいな ことか゛ て゛きた。 ちちは そ゛んらいしなか゛ら、 ひ゛ょうきに かたって、 せ゛っきょうてきな おとこなのて゛、 し゛ふ゛んの あたまを ついに こわささなけれは゛ ならない ひまか゛、 と゛っちに すわっているかを しました」
# 「そういう し゛きと゛いし゛ょう ひようか゛ あります。 し゛っさい しょもつを たしょう た゛んは゜んて゛いましょうか」
# 「ひ゛ょうき゛た゛から て゛きないからね。 ふい ところを つけて きのと゛くて゛さ」
# 「よし゛の かおか゛ た゛けの こみいって、 は゛あいに
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 69/80: イテレーション 6900回
# ----------------------------------------------------------------------
# Train: 1.6512 | Val: 1.8300 | Gap: 0.1787
# ----------------------------------------------------------------------
#
# ろく
# それから その なかたて゛ この し゛しんは まったく し゛んすいの け゛たいて゛あった。 わたしは あによめに すわっていた。 おせんは また この くらい、 あには きゅうりした まわっているかを おもいた゛した。
# わたくしは さらを いた゛ましていたのて゛す。 まったく さんねんに なって やらいに ちか゛いないと おもいましたか゛、 いまの おんなか゛ ふくそうな いみに ちか゛いなと゛は ふくそうなのた゛と いって、 かれは にえんか゛ くるまて゛ かならす゛ やらいの うしろか゛ よけれは゛ ならない つもりて゛す」
# 「と゛ういう まつもとを かってしまったんた゛から、 た゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 70/80: イテレーション 7000回
# ----------------------------------------------------------------------
# Train: 1.6477 | Val: 1.8348 | Gap: 0.1870
# ----------------------------------------------------------------------
#
# ほんにんし゛ゅうはち
# し゛ふ゛ん は おかた゛の ほうへ ある めを きゅうに も くうとした。 かれは ほ゛うよりも はなしはんふ゛んの いんかくに ほっせきしてくれた し゛ふ゛んの うらへ のせた。 し゛つは とうとう つよく はまついて、 すく゛ こう いうような あらさか゛ わかった。 すると し゛ふ゛んも し゛っさい ふきこむ そうな かおを して かおを して 「にいさん きょうし゛ょう、 それて゛も あなた、 はあ たのと みえてたのて゛す。 むるい ない そっちか゛ しってるんた゛からね。 それて゛も おまえの た゛んわさんも かんか゛えていたから、 た゛れも そらか゛ しらな
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 71/80: イテレーション 7100回
# ----------------------------------------------------------------------
# Train: 1.6414 | Val: 1.8322 | Gap: 0.1908
# ----------------------------------------------------------------------
#
# ちちは もとより さきへ なお しょうきゅうねんとして、 たちあか゛って のほ゛った かせ゛も なかった。 かれは すへ゛ての とおり、 たいと゛は かねを たあとから かえってみた。 にか゛わらいの しひ゛きを あけ゛た。 しかし いちは゛ん その ふかいに さんていしていた しせいし゛んと いう ほんひ゛ょうし゛を、 し゛ふ゛んの たかあわせには また゛ それから さむしょに あくる し゛し゛つを、 しし゛ゅた゛いには しせ゛んとか あいてに はしを くわえて、 ほそなか゛い ことの ちゅういを えんりょに のこっているのか、 いま かえって おおきな さきの はなものて゛、 すこし しす
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 72/80: イテレーション 7200回
# ----------------------------------------------------------------------
# Train: 1.6454 | Val: 1.8362 | Gap: 0.1909
# ----------------------------------------------------------------------
#
# 「とつせ゛ん いかな こんな ふうに なるた゛ろう、 と゛う そうて゛すか。 そうた゛って て゛きないて゛すから、 もっとも よいこに たいするうちて゛すって」
# いもう いいから しゅうとした ときは こうせいか゛ ふたりは はならなかった。 それて゛いて、 ほ゛くは いきっと その とき なんの いいふし゛ゅうに おもいた゛したきもりも ある。 ほ゛くは こころの うえに せめられる は゛あいも ないのも、 かんか゛えす゛に この ほんらんか゛ いてた。 へたと けいたろうは その きしゃの こえを た゛して たしょう いたに つつまれていた。 けれと゛も それに まるて゛ ほっこいる とこ
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 73/80: イテレーション 7300回
# ----------------------------------------------------------------------
# Train: 1.6414 | Val: 1.8279 | Gap: 0.1865
# ----------------------------------------------------------------------
#
# 「と゛うしても きいは ないし゛ゃないか」
# あなたは ないかけた。 ほ゛くは こう いった あとて゛ あいれか゛たの うちて゛ かんか゛えているらしく いった。 し゛ふ゛ん この きふ゛んを きくとは、 ここにちまて゛ よさそうに のそ゛いていた。
# 「おさた゛さん こわふ゛りまへとて゛も ないんた゛から」
# すなか゛の は゛あさんを なか゛めていた。 その ある はおりみを こき゛には きの しつもんを もっていた。
# 「いや は゛かりて゛しょう」
# はヴぁわんの のへ゛も はいるに ともた゛ちか゛ かわって、 すて゛に さうしゅくから いす゛れは゛ また きかせた。
# し゛ふ゛ん その すすめられた
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 74/80: イテレーション 7400回
# ----------------------------------------------------------------------
# Train: 1.6316 | Val: 1.8296 | Gap: 0.1980
# ----------------------------------------------------------------------
#
# わたくしは まうもとの ちゅういに この にて゛ あった。 そうして せんせいと わたくしは おくさんとして いつわりに こんさ゛いを かんか゛えた。 そのとき わたくしは また ひし゛ょうかんまえ きか゛ついた ものか゛、 「あの おんな」の せまい かおを みて、 また わたしの そうし゛んに ついた。 そうして て゛なかったか゛、 くちを かけて きこえた わたしは ふくに て゛きあか゛って、 わたしは はし゛めの くす゛れに すわっている ふうに、 と むか゛いあく゛らい すこなか゛ら、 きゅうに しんは゜いしている かおを していたからて゛ある。
# わたしは てに こうにいか ついた。
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 75/80: イテレーション 7500回
# ----------------------------------------------------------------------
# Train: 1.6317 | Val: 1.8259 | Gap: 0.1942
# ----------------------------------------------------------------------
#
# それか゛ のちへ ちゅうしの かにほうもんを みると、 えんりょない おんなて゛あった。 それか゛ また おくさんに こいしくって、 よしえて いしゃの うらの ほうは からた゛を かさねたとき、 うるわけの こ゛とく やきまて゛ まえの なかて゛、 あとて゛も とっくりしたとて゛、 しは゛らく いうと、 かのし゛ょの わかた゛の かおに いたった かんしゃには、 えっきゅうて゛ この ひた゛りの まんなかに あきらました。 わたしは こんな おし゛ょうさんか゛ おさた゛さんの し゛しんを すなわち と゛うし゛ょう ひょうしか た゛んた゛ん おかた゛と わたしに したものた゛と いう かんさつ
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 76/80: イテレーション 7600回
# ----------------------------------------------------------------------
# Train: 1.6280 | Val: 1.8191 | Gap: 0.1912
# ----------------------------------------------------------------------
#
# 「たり」
# 「ねえさん わからない あなたから ゆっくり」と いった。 おかねさんは おし゛ょうさんへ きて、 おかた゛の いえを えんりょして あての はなを した。 「まったく おとうさんに いうから」 と みさわは とい おんなの にんけ゛んを みた。
# さん
# ちちは かれの ひとは゛んの ような ために なるように みえた。 そうして かのし゛ょの さいか゛ きっと おおさかさかに むかって せっきょくてきに あそひ゛かえていた。
# こんにちまて゛ おかねさんの しす゛かな こころもちか゛ きて、 やくし゛ほうと あめの おおきな こえを おりて、 うちあけ゛る かれは また きおくの こ゛
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 77/80: イテレーション 7700回
# ----------------------------------------------------------------------
# Train: 1.6205 | Val: 1.8348 | Gap: 0.2143
# ----------------------------------------------------------------------
#
# 「し゛つは と゛うしたら、 きょうた゛い」と わたくしか゛ いった。 わたしは ことさらに とけいたろうか゛ はくした。 えんか゛わの なかを いうのか゛ きに ゆるすんて゛いるなら すこしか゛ よく わからなかった。
# みさわは この こき゛か゛ ねつかえないと いう けいたろうを ひは゛ちを のそ゛いた。 し゛ふ゛んも ちちか゛ はしこ゛た゛んに へ゛んかいした。 それて゛ し゛ふ゛んは こころの こころもちに まか゛ろうと まっているた゛ろうと みえた おほ゛えも ことか゛ て゛きなかったのて゛ある。 こうして かれの さっきは とつせ゛ん ふしんの うえに きた。
# 「おかあさんは ええさ
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 78/80: イテレーション 7800回
# ----------------------------------------------------------------------
# Train: 1.6187 | Val: 1.8245 | Gap: 0.2058
# ----------------------------------------------------------------------
#
# くったくしても、 たのまえに ほしょうしたことか゛ て゛きないのて゛す。 わたしは ちちの ところて゛す。 Kに わたしを そうそ゛うするこーとの しょうそくを おもいた゛しますから、 かれか゛ いやなと゛は けっしても、 ちちの ふしき゛に すわりうことの しゅた゛んは とくきょうなやに この ねんけいか゛ ゆきに なった ことか゛ なけれは゛ ならないのた゛と たす゛ねた。 おれは ねほんと おきのと゛くしゃの やと゛に しゅっさいの よく のった かのし゛ょの あいた゛から おそれる わけにも いかなかった。
# して あにの きしょうか゛ わからなかった。
# あにの は゛あいさえ ひとは も
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 79/80: イテレーション 7900回
# ----------------------------------------------------------------------
# Train: 1.6182 | Val: 1.8120 | Gap: 0.1939
# ----------------------------------------------------------------------
#
# 「けんき た゛いし゛ゃ ついそ゛ なかろうと いいましたから」
# こう いって、 たす゛ねた ことは゛を、 らんかんするのは きに ならないのて゛す。 それて゛も むやみの いと゛て゛も、 わたしは それを さく゛ったまま もんた゛いしたのて゛す。 ところか゛ おくさんは と゛こにも せひ゛こんて゛いるんた゛から、 あの さないと いう けんしょうさんを おと゛ろかされたうえ、 あう ことに こわいものを かかったとき゛も、 そのは゛ん ははの つよみか゛ く゛るく゛る て゛んわを おりるうちに、 なお し゛ふ゛んの かたつ゛いて ひふりの めを みたのた゛。
# あると あにには うちへ て゛たと
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 📈 チェックポイント 80/80: イテレーション 7999回
# ----------------------------------------------------------------------
#
# そこへ まし゛めに おうし゛て、 その みす゛かの うちに ふりつき゛の ひろい、 かつて とって かえって むこうか゛ ない ほそなか゛い いっしょに なった。 しろう ひとか゛ ないと いった おなし゛ てか゛みを た゛していた いした゛いは、 それて゛も とくへ゛つ おそうのように おもわれている。
# さんし゛ゅうきょうとか いうと、 それか゛ ふ゛っしょくに その ふとんを かけて まちもうけられるたは゛かりて゛あった。 この おんなの うちて゛ すて゛に ある すてっきとしか はなれさ゛る はか゛きを、 その とおりの いうこしに おちて、 しけんな うちこわす゛に きた。 かまくらと
# ----------------------------------------------------------------------
# 💭 学習完了 - より自然で意味のある文章を生成
#
# ======================================================================
# 🎉 すべてのチェックポイントのテスト完了
# ======================================================================

# %% [markdown]
# ## 7️⃣ インタラクティブな文章生成
#
# 最終モデルを使って、自由に文章を生成してみましょう。

# %%
# 最終モデルをロード
checkpoint = torch.load(final_path, weights_only=False)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

print("\n🎮 インタラクティブ生成モード")
print("="*70)
print("下のセルのプロンプトを変更して、文章を生成してみましょう。")
print("="*70)
# Out:
# 🎮 インタラクティブ生成モード
# ======================================================================
# 下のセルのプロンプトを変更して、文章を生成してみましょう。
# ======================================================================

# %%
# プロンプトを設定（空の場合はランダム生成）
prompt = "わたくし は"  # ← ここを変更してみてください
max_generate = 500     # 生成する文字数

print(f"\n💬 プロンプト: '{prompt}'")
print(f"📝 生成文字数: {max_generate}")
print("-"*70)

if prompt:
    context = torch.tensor([encode(prompt)], dtype=torch.long, device=device)
else:
    context = torch.zeros((1, 1), dtype=torch.long, device=device)

with torch.no_grad():
    generated = decode(model.generate(context, max_new_tokens=max_generate)[0].tolist())

print(generated)
print("-"*70)
# Out:
# 💬 プロンプト: 'わたくし は'
# 📝 生成文字数: 500
# ----------------------------------------------------------------------
# わたくし はなしているのて゛す。 わたしは しす゛かて゛は、 せんせいと ふとうを おいて しは゛らく にき゛った。 ひっきょうな もんた゛いは けいたろうの とおりなと゛を よるほと゛ いろいろ ひとりも なかった。 しかし わたしは それか゛ ゆうきゅうしなくなっていたような こたえた。 きくか゛ むねを ある せんせいの おくて゛す。 わたしは たた゛ わたくしの うちわを したものか゛、 この あたまと それから すく゛ おもい きっと はたして しす゛かしないのて゛、 むろん し゛ふ゛んには こ゛ろく しておくか゛、 かのし゛ょに うったえの えんりょなく みせました。 そのひも かれの ねつは その はし゛めから つい むき゛わらほ゛うを にし゛ょうしていたのた゛と いうことに、 ある おとこと いう ことは゛は ないと こたえました。 しかし もう て゛んわの いっている りょうけんの ほうか゛ ことさらに もってから かねていないと おもって、 せ゛んたいから、 いちにち とさ゛てとも しんは゜いしている やさしい ふ゛んちょうたを みうけて きたのを また ひっくり みたのて゛あ
# ----------------------------------------------------------------------

# %% [markdown]
# ## 🎓 まとめ
#
# このノートブックでは、以下のことを学びました：
#
# ### 📚 Transformerの基礎
# 1. **Self-Attention機構** - 文章内の単語間の関係を学習
# 2. **Multi-Head Attention** - 複数の視点から文脈を捉える
# 3. **Feed Forward Network** - 各単語の特徴を変換
# 4. **Layer Normalization** - 学習の安定化
# 5. **Residual Connection** - 深いネットワークの学習を可能に
#
# ### 🛡️ 過学習対策
# 1. **Dropout** - ランダムにニューロンを無効化
# 2. **Weight Decay** - L2正則化でパラメータの増大を抑制
# 3. **Gradient Clipping** - 勾配爆発の防止
# 4. **Early Stopping** - 過学習の兆候で自動停止
# 5. **適切なモデルサイズ** - データ量に応じた設計
#
# ### 💡 さらに学ぶには
# - より大きなデータセットで学習
# - ハイパーパラメータの調整
# - Temperature パラメータによる生成制御
# - Beam Searchなどの高度な生成手法
#
# ---
#
# お疲れ様でした！🎉
